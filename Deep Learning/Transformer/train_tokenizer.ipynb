# %%
import os

# Import custom modules
from src import Tokenizer

# %% [markdown]
# ### Constants and hyperparameters

# %%
# Constants
save_state = True # Save the state of the tokenizer into a local file
dataset_path = os.path.join(os.getcwd(), 'dataset', 'input.txt') # Path to the training dataset
output_path = os.path.join(os.getcwd(), 'checkpoints', 'tokenizer.json') # Path into which the tokenized parameters will be saved

# %%
# Hyperparameters
vocab_size = 1024 # The size of the vocabulary
validation_samples = 250 # Number of samples to use for validation

# %% [markdown]
# ### Data loading

# %%
def load_txt_file(path: str) -> str:
    """
    Load a text file from the specified path.
    
    Parameters:
    - path (str): The path to the text file.
    
    Returns:
    - str: The contents of the text file.
    """
    
    # Check if the file exists
    if not os.path.exists(path):
        raise FileNotFoundError(f'The file "{path}" does not exist.')
    
    # Read the file
    with open(path, 'r', encoding='utf-8') as file:
        return file.read()

# %%
# Load the text file
text = load_txt_file(dataset_path)

# Split the text into training and validation sets
training_text = text[:(len(text) - validation_samples if len(text) > validation_samples else -1)]
validation_text = text[-validation_samples:]

# Print the number of samples in each set
print(f"Training text length: {len(training_text)}")
print(f"Validation text length: {len(validation_text)}")
# Out:
# Training text length: 294935
# Validation text length: 250

# %% [markdown]
# ### Tokenizer

# %%
# Instantiate the tokenizer
tokenizer = Tokenizer()

# %% [markdown]
# ### Training the tokenizer

# %%
# Train the tokenizer
tokenizer.train(text=training_text, vocab_size=vocab_size)
# Out:
# 1/768 --> Merged tokens (101, 32) into token 256
# 2/768 --> Merged tokens (97, 32) into token 257
# 3/768 --> Merged tokens (105, 32) into token 258
# 4/768 --> Merged tokens (111, 32) into token 259
# 5/768 --> Merged tokens (101, 114) into token 260
# 6/768 --> Merged tokens (99, 104) into token 261
# 7/768 --> Merged tokens (110, 32) into token 262
# 8/768 --> Merged tokens (108, 32) into token 263
# 9/768 --> Merged tokens (99, 111) into token 264
# 10/768 --> Merged tokens (97, 110) into token 265
# 11/768 --> Merged tokens (44, 10) into token 266
# 12/768 --> Merged tokens (101, 110) into token 267
# 13/768 --> Merged tokens (97, 114) into token 268
# 14/768 --> Merged tokens (44, 32) into token 269
# 15/768 --> Merged tokens (108, 108) into token 270
# 16/768 --> Merged tokens (261, 256) into token 271
# 17/768 --> Merged tokens (111, 114) into token 272
# 18/768 --> Merged tokens (115, 116) into token 273
# 19/768 --> Merged tokens (113, 117) into token 274
# 20/768 --> Merged tokens (260, 32) into token 275
# 21/768 --> Merged tokens (46, 10) into token 276
# 22/768 --> Merged tokens (110, 111) into token 277
# 23/768 --> Merged tokens (100, 101) into token 278
# 24/768 --> Merged tokens (116, 116) into token 279
# 25/768 --> Merged tokens (114, 105) into token 280
# 26/768 --> Merged tokens (100, 258) into token 281
# 27/768 --> Merged tokens (105, 110) into token 282
# 28/768 --> Merged tokens (115, 115) into token 283
# 29/768 --> Merged tokens (97, 108) into token 284
# 30/768 --> Merged tokens (100, 105) into token 285
# 31/768 --> Merged tokens (116, 114) into token 286
# 32/768 --> Merged tokens (111, 110) into token 287
# 33/768 --> Merged tokens (108, 257) into token 288
# 34/768 --> Merged tokens (105, 259) into token 289
# 35/768 --> Merged tokens (114, 97) into token 290
# 36/768 --> Merged tokens (111, 108) into token 291
# 37/768 --> Merged tokens (99, 105) into token 292
# 38/768 --> Merged tokens (112, 275) into token 293
# 39/768 --> Merged tokens (115, 117) into token 294
# 40/768 --> Merged tokens (118, 105) into token 295
# 41/768 --> Merged tokens (116, 101) into token 296
# 42/768 --> Merged tokens (114, 101) into token 297
# 43/768 --> Merged tokens (116, 259) into token 298
# 44/768 --> Merged tokens (115, 258) into token 299
# 45/768 --> Merged tokens (274, 101) into token 300
# 46/768 --> Merged tokens (116, 117) into token 301
# 47/768 --> Merged tokens (97, 10) into token 302
# 48/768 --> Merged tokens (115, 111) into token 303
# 49/768 --> Merged tokens (105, 262) into token 304
# 50/768 --> Merged tokens (115, 101) into token 305
# 51/768 --> Merged tokens (97, 263) into token 306
# 52/768 --> Merged tokens (103, 105) into token 307
# 53/768 --> Merged tokens (118, 101) into token 308
# 54/768 --> Merged tokens (59, 10) into token 309
# 55/768 --> Merged tokens (109, 256) into token 310
# 56/768 --> Merged tokens (116, 256) into token 311
# 57/768 --> Merged tokens (108, 39) into token 312
# 58/768 --> Merged tokens (97, 266) into token 313
# 59/768 --> Merged tokens (270, 257) into token 314
# 60/768 --> Merged tokens (109, 105) into token 315
# 61/768 --> Merged tokens (100, 259) into token 316
# 62/768 --> Merged tokens (277, 262) into token 317
# 63/768 --> Merged tokens (272, 32) into token 318
# 64/768 --> Merged tokens (112, 111) into token 319
# 65/768 --> Merged tokens (97, 99) into token 320
# 66/768 --> Merged tokens (108, 105) into token 321
# 67/768 --> Merged tokens (39, 32) into token 322
# 68/768 --> Merged tokens (97, 109) into token 323
# 69/768 --> Merged tokens (111, 10) into token 324
# 70/768 --> Merged tokens (117, 110) into token 325
# 71/768 --> Merged tokens (112, 105) into token 326
# 72/768 --> Merged tokens (261, 39) into token 327
# 73/768 --> Merged tokens (116, 105) into token 328
# 74/768 --> Merged tokens (110, 101) into token 329
# 75/768 --> Merged tokens (109, 258) into token 330
# 76/768 --> Merged tokens (111, 266) into token 331
# 77/768 --> Merged tokens (112, 268) into token 332
# 78/768 --> Merged tokens (105, 263) into token 333
# 79/768 --> Merged tokens (115, 256) into token 334
# 80/768 --> Merged tokens (102, 117) into token 335
# 81/768 --> Merged tokens (115, 105) into token 336
# 82/768 --> Merged tokens (97, 118) into token 337
# 83/768 --> Merged tokens (111, 269) into token 338
# 84/768 --> Merged tokens (108, 256) into token 339
# 85/768 --> Merged tokens (115, 99) into token 340
# 86/768 --> Merged tokens (268, 32) into token 341
# 87/768 --> Merged tokens (114, 257) into token 342
# 88/768 --> Merged tokens (116, 258) into token 343
# 89/768 --> Merged tokens (39, 263) into token 344
# 90/768 --> Merged tokens (108, 258) into token 345
# 91/768 --> Merged tokens (109, 97) into token 346
# 92/768 --> Merged tokens (264, 262) into token 347
# 93/768 --> Merged tokens (264, 110) into token 348
# 94/768 --> Merged tokens (109, 257) into token 349
# 95/768 --> Merged tokens (103, 110) into token 350
# 96/768 --> Merged tokens (111, 99) into token 351
# 97/768 --> Merged tokens (100, 39) into token 352
# 98/768 --> Merged tokens (109, 101) into token 353
# 99/768 --> Merged tokens (97, 276) into token 354
# 100/768 --> Merged tokens (264, 114) into token 355
# 101/768 --> Merged tokens (117, 262) into token 356
# 102/768 --> Merged tokens (103, 117) into token 357
# 103/768 --> Merged tokens (97, 270) into token 358
# 104/768 --> Merged tokens (116, 257) into token 359
# 105/768 --> Merged tokens (102, 105) into token 360
# 106/768 --> Merged tokens (279, 259) into token 361
# 107/768 --> Merged tokens (278, 263) into token 362
# 108/768 --> Merged tokens (284, 286) into token 363
# 109/768 --> Merged tokens (115, 112) into token 364
# 110/768 --> Merged tokens (108, 117) into token 365
# 111/768 --> Merged tokens (100, 257) into token 366
# 112/768 --> Merged tokens (118, 291) into token 367
# 113/768 --> Merged tokens (108, 259) into token 368
# 114/768 --> Merged tokens (97, 269) into token 369
# 115/768 --> Merged tokens (118, 260) into token 370
# 116/768 --> Merged tokens (103, 321) into token 371
# 117/768 --> Merged tokens (108, 101) into token 372
# 118/768 --> Merged tokens (264, 310) into token 373
# 119/768 --> Merged tokens (114, 111) into token 374
# 120/768 --> Merged tokens (101, 283) into token 375
# 121/768 --> Merged tokens (265, 316) into token 376
# 122/768 --> Merged tokens (261, 105) into token 377
# 123/768 --> Merged tokens (101, 10) into token 378
# 124/768 --> Merged tokens (112, 260) into token 379
# 125/768 --> Merged tokens (109, 111) into token 380
# 126/768 --> Merged tokens (58, 10) into token 381
# 127/768 --> Merged tokens (112, 280) into token 382
# 128/768 --> Merged tokens (97, 283) into token 383
# 129/768 --> Merged tokens (102, 101) into token 384
# 130/768 --> Merged tokens (118, 267) into token 385
# 131/768 --> Merged tokens (100, 111) into token 386
# 132/768 --> Merged tokens (109, 267) into token 387
# 133/768 --> Merged tokens (100, 117) into token 388
# 134/768 --> Merged tokens (101, 269) into token 389
# 135/768 --> Merged tokens (100, 256) into token 390
# 136/768 --> Merged tokens (114, 32) into token 391
# 137/768 --> Merged tokens (261, 258) into token 392
# 138/768 --> Merged tokens (265, 122) into token 393
# 139/768 --> Merged tokens (115, 39) into token 394
# 140/768 --> Merged tokens (101, 266) into token 395
# 141/768 --> Merged tokens (265, 298) into token 396
# 142/768 --> Merged tokens (100, 32) into token 397
# 143/768 --> Merged tokens (98, 105) into token 398
# 144/768 --> Merged tokens (109, 259) into token 399
# 145/768 --> Merged tokens (111, 262) into token 400
# 146/768 --> Merged tokens (122, 105) into token 401
# 147/768 --> Merged tokens (98, 101) into token 402
# 148/768 --> Merged tokens (300, 273) into token 403
# 149/768 --> Merged tokens (111, 276) into token 404
# 150/768 --> Merged tokens (110, 259) into token 405
# 151/768 --> Merged tokens (97, 262) into token 406
# 152/768 --> Merged tokens (115, 259) into token 407
# 153/768 --> Merged tokens (99, 117) into token 408
# 154/768 --> Merged tokens (118, 111) into token 409
# 155/768 --> Merged tokens (99, 97) into token 410
# 156/768 --> Merged tokens (99, 256) into token 411
# 157/768 --> Merged tokens (273, 114) into token 412
# 158/768 --> Merged tokens (112, 117) into token 413
# 159/768 --> Merged tokens (260, 257) into token 414
# 160/768 --> Merged tokens (278, 270) into token 415
# 161/768 --> Merged tokens (101, 279) into token 416
# 162/768 --> Merged tokens (109, 265) into token 417
# 163/768 --> Merged tokens (115, 292) into token 418
# 164/768 --> Merged tokens (300, 263) into token 419
# 165/768 --> Merged tokens (103, 307) into token 420
# 166/768 --> Merged tokens (97, 279) into token 421
# 167/768 --> Merged tokens (109, 112) into token 422
# 168/768 --> Merged tokens (97, 258) into token 423
# 169/768 --> Merged tokens (109, 39) into token 424
# 170/768 --> Merged tokens (99, 259) into token 425
# 171/768 --> Merged tokens (69, 32) into token 426
# 172/768 --> Merged tokens (97, 314) into token 427
# 173/768 --> Merged tokens (103, 290) into token 428
# 174/768 --> Merged tokens (105, 10) into token 429
# 175/768 --> Merged tokens (301, 279) into token 430
# 176/768 --> Merged tokens (105, 269) into token 431
# 177/768 --> Merged tokens (122, 122) into token 432
# 178/768 --> Merged tokens (329, 263) into token 433
# 179/768 --> Merged tokens (102, 272) into token 434
# 180/768 --> Merged tokens (116, 272) into token 435
# 181/768 --> Merged tokens (278, 314) into token 436
# 182/768 --> Merged tokens (114, 256) into token 437
# 183/768 --> Merged tokens (112, 297) into token 438
# 184/768 --> Merged tokens (101, 270) into token 439
# 185/768 --> Merged tokens (109, 287) into token 440
# 186/768 --> Merged tokens (116, 97) into token 441
# 187/768 --> Merged tokens (294, 259) into token 442
# 188/768 --> Merged tokens (105, 266) into token 443
# 189/768 --> Merged tokens (101, 276) into token 444
# 190/768 --> Merged tokens (116, 260) into token 445
# 191/768 --> Merged tokens (286, 259) into token 446
# 192/768 --> Merged tokens (116, 267) into token 447
# 193/768 --> Merged tokens (102, 111) into token 448
# 194/768 --> Merged tokens (118, 256) into token 449
# 195/768 --> Merged tokens (103, 267) into token 450
# 196/768 --> Merged tokens (258, 271) into token 451
# 197/768 --> Merged tokens (265, 100) into token 452
# 198/768 --> Merged tokens (59, 32) into token 453
# 199/768 --> Merged tokens (325, 257) into token 454
# 200/768 --> Merged tokens (108, 97) into token 455
# 201/768 --> Merged tokens (97, 112) into token 456
# 202/768 --> Merged tokens (81, 117) into token 457
# 203/768 --> Merged tokens (294, 257) into token 458
# 204/768 --> Merged tokens (108, 318) into token 459
# 205/768 --> Merged tokens (98, 98) into token 460
# 206/768 --> Merged tokens (97, 308) into token 461
# 207/768 --> Merged tokens (269, 256) into token 462
# 208/768 --> Merged tokens (118, 257) into token 463
# 209/768 --> Merged tokens (301, 32) into token 464
# 210/768 --> Merged tokens (100, 275) into token 465
# 211/768 --> Merged tokens (309, 256) into token 466
# 212/768 --> Merged tokens (111, 109) into token 467
# 213/768 --> Merged tokens (110, 256) into token 468
# 214/768 --> Merged tokens (112, 97) into token 469
# 215/768 --> Merged tokens (296, 10) into token 470
# 216/768 --> Merged tokens (335, 32) into token 471
# 217/768 --> Merged tokens (256, 256) into token 472
# 218/768 --> Merged tokens (110, 97) into token 473
# 219/768 --> Merged tokens (101, 397) into token 474
# 220/768 --> Merged tokens (265, 116) into token 475
# 221/768 --> Merged tokens (116, 396) into token 476
# 222/768 --> Merged tokens (109, 272) into token 477
# 223/768 --> Merged tokens (100, 267) into token 478
# 224/768 --> Merged tokens (294, 32) into token 479
# 225/768 --> Merged tokens (101, 263) into token 480
# 226/768 --> Merged tokens (257, 271) into token 481
# 227/768 --> Merged tokens (111, 258) into token 482
# 228/768 --> Merged tokens (103, 103) into token 483
# 229/768 --> Merged tokens (274, 376) into token 484
# 230/768 --> Merged tokens (112, 267) into token 485
# 231/768 --> Merged tokens (327, 289) into token 486
# 232/768 --> Merged tokens (118, 258) into token 487
# 233/768 --> Merged tokens (351, 392) into token 488
# 234/768 --> Merged tokens (116, 280) into token 489
# 235/768 --> Merged tokens (99, 101) into token 490
# 236/768 --> Merged tokens (303, 262) into token 491
# 237/768 --> Merged tokens (259, 256) into token 492
# 238/768 --> Merged tokens (102, 260) into token 493
# 239/768 --> Merged tokens (99, 297) into token 494
# 240/768 --> Merged tokens (363, 259) into token 495
# 241/768 --> Merged tokens (109, 289) into token 496
# 242/768 --> Merged tokens (358, 39) into token 497
# 243/768 --> Merged tokens (300, 270) into token 498
# 244/768 --> Merged tokens (257, 256) into token 499
# 245/768 --> Merged tokens (115, 291) into token 500
# 246/768 --> Merged tokens (273, 105) into token 501
# 247/768 --> Merged tokens (260, 256) into token 502
# 248/768 --> Merged tokens (101, 99) into token 503
# 249/768 --> Merged tokens (393, 257) into token 504
# 250/768 --> Merged tokens (102, 97) into token 505
# 251/768 --> Merged tokens (10, 10) into token 506
# 252/768 --> Merged tokens (283, 256) into token 507
# 253/768 --> Merged tokens (115, 326) into token 508
# 254/768 --> Merged tokens (296, 266) into token 509
# 255/768 --> Merged tokens (111, 350) into token 510
# 256/768 --> Merged tokens (300, 314) into token 511
# 257/768 --> Merged tokens (100, 291) into token 512
# 258/768 --> Merged tokens (116, 111) into token 513
# 259/768 --> Merged tokens (112, 374) into token 514
# 260/768 --> Merged tokens (292, 97) into token 515
# 261/768 --> Merged tokens (258, 256) into token 516
# 262/768 --> Merged tokens (115, 267) into token 517
# 263/768 --> Merged tokens (115, 260) into token 518
# 264/768 --> Merged tokens (103, 101) into token 519
# 265/768 --> Merged tokens (116, 302) into token 520
# 266/768 --> Merged tokens (274, 306) into token 521
# 267/768 --> Merged tokens (415, 39) into token 522
# 268/768 --> Merged tokens (114, 267) into token 523
# 269/768 --> Merged tokens (101, 262) into token 524
# 270/768 --> Merged tokens (112, 272) into token 525
# 271/768 --> Merged tokens (268, 256) into token 526
# 272/768 --> Merged tokens (257, 281) into token 527
# 273/768 --> Merged tokens (114, 117) into token 528
# 274/768 --> Merged tokens (268, 100) into token 529
# 275/768 --> Merged tokens (295, 281) into token 530
# 276/768 --> Merged tokens (105, 322) into token 531
# 277/768 --> Merged tokens (265, 105) into token 532
# 278/768 --> Merged tokens (116, 306) into token 533
# 279/768 --> Merged tokens (365, 258) into token 534
# 280/768 --> Merged tokens (355, 32) into token 535
# 281/768 --> Merged tokens (116, 331) into token 536
# 282/768 --> Merged tokens (273, 259) into token 537
# 283/768 --> Merged tokens (286, 257) into token 538
# 284/768 --> Merged tokens (271, 344) into token 539
# 285/768 --> Merged tokens (315, 257) into token 540
# 286/768 --> Merged tokens (286, 97) into token 541
# 287/768 --> Merged tokens (99, 268) into token 542
# 288/768 --> Merged tokens (307, 117) into token 543
# 289/768 --> Merged tokens (97, 397) into token 544
# 290/768 --> Merged tokens (264, 108) into token 545
# 291/768 --> Merged tokens (412, 259) into token 546
# 292/768 --> Merged tokens (413, 391) into token 547
# 293/768 --> Merged tokens (99, 258) into token 548
# 294/768 --> Merged tokens (115, 287) into token 549
# 295/768 --> Merged tokens (116, 313) into token 550
# 296/768 --> Merged tokens (102, 320) into token 551
# 297/768 --> Merged tokens (97, 309) into token 552
# 298/768 --> Merged tokens (99, 260) into token 553
# 299/768 --> Merged tokens (301, 361) into token 554
# 300/768 --> Merged tokens (329, 270) into token 555
# 301/768 --> Merged tokens (99, 267) into token 556
# 302/768 --> Merged tokens (114, 265) into token 557
# 303/768 --> Merged tokens (402, 262) into token 558
# 304/768 --> Merged tokens (116, 324) into token 559
# 305/768 --> Merged tokens (284, 105) into token 560
# 306/768 --> Merged tokens (337, 257) into token 561
# 307/768 --> Merged tokens (277, 10) into token 562
# 308/768 --> Merged tokens (338, 256) into token 563
# 309/768 --> Merged tokens (277, 266) into token 564
# 310/768 --> Merged tokens (273, 342) into token 565
# 311/768 --> Merged tokens (286, 256) into token 566
# 312/768 --> Merged tokens (109, 117) into token 567
# 313/768 --> Merged tokens (285, 115) into token 568
# 314/768 --> Merged tokens (112, 383) into token 569
# 315/768 --> Merged tokens (453, 256) into token 570
# 316/768 --> Merged tokens (265, 405) into token 571
# 317/768 --> Merged tokens (112, 259) into token 572
# 318/768 --> Merged tokens (98, 117) into token 573
# 319/768 --> Merged tokens (118, 275) into token 574
# 320/768 --> Merged tokens (99, 257) into token 575
# 321/768 --> Merged tokens (115, 504) into token 576
# 322/768 --> Merged tokens (335, 318) into token 577
# 323/768 --> Merged tokens (109, 282) into token 578
# 324/768 --> Merged tokens (100, 306) into token 579
# 325/768 --> Merged tokens (273, 257) into token 580
# 326/768 --> Merged tokens (109, 399) into token 581
# 327/768 --> Merged tokens (104, 257) into token 582
# 328/768 --> Merged tokens (112, 101) into token 583
# 329/768 --> Merged tokens (265, 535) into token 584
# 330/768 --> Merged tokens (100, 260) into token 585
# 331/768 --> Merged tokens (345, 488) into token 586
# 332/768 --> Merged tokens (461, 257) into token 587
# 333/768 --> Merged tokens (115, 265) into token 588
# 334/768 --> Merged tokens (363, 257) into token 589
# 335/768 --> Merged tokens (387, 311) into token 590
# 336/768 --> Merged tokens (115, 257) into token 591
# 337/768 --> Merged tokens (296, 276) into token 592
# 338/768 --> Merged tokens (408, 258) into token 593
# 339/768 --> Merged tokens (293, 368) into token 594
# 340/768 --> Merged tokens (323, 267) into token 595
# 341/768 --> Merged tokens (77, 257) into token 596
# 342/768 --> Merged tokens (101, 460) into token 597
# 343/768 --> Merged tokens (97, 298) into token 598
# 344/768 --> Merged tokens (109, 268) into token 599
# 345/768 --> Merged tokens (105, 276) into token 600
# 346/768 --> Merged tokens (118, 282) into token 601
# 347/768 --> Merged tokens (319, 258) into token 602
# 348/768 --> Merged tokens (274, 396) into token 603
# 349/768 --> Merged tokens (114, 259) into token 604
# 350/768 --> Merged tokens (100, 287) into token 605
# 351/768 --> Merged tokens (278, 322) into token 606
# 352/768 --> Merged tokens (103, 104) into token 607
# 353/768 --> Merged tokens (510, 258) into token 608
# 354/768 --> Merged tokens (287, 390) into token 609
# 355/768 --> Merged tokens (110, 117) into token 610
# 356/768 --> Merged tokens (320, 274) into token 611
# 357/768 --> Merged tokens (100, 282) into token 612
# 358/768 --> Merged tokens (101, 257) into token 613
# 359/768 --> Merged tokens (290, 266) into token 614
# 360/768 --> Merged tokens (115, 97) into token 615
# 361/768 --> Merged tokens (284, 99) into token 616
# 362/768 --> Merged tokens (269, 271) into token 617
# 363/768 --> Merged tokens (290, 10) into token 618
# 364/768 --> Merged tokens (403, 257) into token 619
# 365/768 --> Merged tokens (327, 531) into token 620
# 366/768 --> Merged tokens (467, 98) into token 621
# 367/768 --> Merged tokens (102, 257) into token 622
# 368/768 --> Merged tokens (357, 105) into token 623
# 369/768 --> Merged tokens (118, 97) into token 624
# 370/768 --> Merged tokens (293, 288) into token 625
# 371/768 --> Merged tokens (393, 258) into token 626
# 372/768 --> Merged tokens (382, 349) into token 627
# 373/768 --> Merged tokens (101, 258) into token 628
# 374/768 --> Merged tokens (285, 101) into token 629
# 375/768 --> Merged tokens (515, 340) into token 630
# 376/768 --> Merged tokens (264, 263) into token 631
# 377/768 --> Merged tokens (283, 259) into token 632
# 378/768 --> Merged tokens (403, 259) into token 633
# 379/768 --> Merged tokens (375, 275) into token 634
# 380/768 --> Merged tokens (67, 111) into token 635
# 381/768 --> Merged tokens (326, 265) into token 636
# 382/768 --> Merged tokens (102, 282) into token 637
# 383/768 --> Merged tokens (110, 257) into token 638
# 384/768 --> Merged tokens (271, 288) into token 639
# 385/768 --> Merged tokens (346, 258) into token 640
# 386/768 --> Merged tokens (116, 265) into token 641
# 387/768 --> Merged tokens (312, 97) into token 642
# 388/768 --> Merged tokens (277, 258) into token 643
# 389/768 --> Merged tokens (388, 256) into token 644
# 390/768 --> Merged tokens (108, 289) into token 645
# 391/768 --> Merged tokens (286, 111) into token 646
# 392/768 --> Merged tokens (73, 259) into token 647
# 393/768 --> Merged tokens (264, 273) into token 648
# 394/768 --> Merged tokens (303, 361) into token 649
# 395/768 --> Merged tokens (278, 266) into token 650
# 396/768 --> Merged tokens (358, 256) into token 651
# 397/768 --> Merged tokens (116, 284) into token 652
# 398/768 --> Merged tokens (39, 110) into token 653
# 399/768 --> Merged tokens (305, 10) into token 654
# 400/768 --> Merged tokens (117, 111) into token 655
# 401/768 --> Merged tokens (274, 258) into token 656
# 402/768 --> Merged tokens (357, 529) into token 657
# 403/768 --> Merged tokens (101, 273) into token 658
# 404/768 --> Merged tokens (352, 289) into token 659
# 405/768 --> Merged tokens (278, 10) into token 660
# 406/768 --> Merged tokens (305, 266) into token 661
# 407/768 --> Merged tokens (98, 267) into token 662
# 408/768 --> Merged tokens (261, 289) into token 663
# 409/768 --> Merged tokens (304, 479) into token 664
# 410/768 --> Merged tokens (261, 389) into token 665
# 411/768 --> Merged tokens (369, 256) into token 666
# 412/768 --> Merged tokens (108, 272) into token 667
# 413/768 --> Merged tokens (296, 422) into token 668
# 414/768 --> Merged tokens (274, 105) into token 669
# 415/768 --> Merged tokens (340, 267) into token 670
# 416/768 --> Merged tokens (445, 342) into token 671
# 417/768 --> Merged tokens (103, 111) into token 672
# 418/768 --> Merged tokens (114, 287) into token 673
# 419/768 --> Merged tokens (313, 256) into token 674
# 420/768 --> Merged tokens (303, 118) into token 675
# 421/768 --> Merged tokens (319, 425) into token 676
# 422/768 --> Merged tokens (103, 259) into token 677
# 423/768 --> Merged tokens (265, 328) into token 678
# 424/768 --> Merged tokens (448, 283) into token 679
# 425/768 --> Merged tokens (115, 268) into token 680
# 426/768 --> Merged tokens (33, 10) into token 681
# 427/768 --> Merged tokens (312, 117) into token 682
# 428/768 --> Merged tokens (274, 284) into token 683
# 429/768 --> Merged tokens (256, 281) into token 684
# 430/768 --> Merged tokens (440, 316) into token 685
# 431/768 --> Merged tokens (259, 257) into token 686
# 432/768 --> Merged tokens (450, 311) into token 687
# 433/768 --> Merged tokens (122, 257) into token 688
# 434/768 --> Merged tokens (101, 309) into token 689
# 435/768 --> Merged tokens (103, 280) into token 690
# 436/768 --> Merged tokens (308, 465) into token 691
# 437/768 --> Merged tokens (115, 264) into token 692
# 438/768 --> Merged tokens (109, 291) into token 693
# 439/768 --> Merged tokens (329, 314) into token 694
# 440/768 --> Merged tokens (108, 111) into token 695
# 441/768 --> Merged tokens (416, 260) into token 696
# 442/768 --> Merged tokens (97, 322) into token 697
# 443/768 --> Merged tokens (116, 404) into token 698
# 444/768 --> Merged tokens (278, 279) into token 699
# 445/768 --> Merged tokens (430, 258) into token 700
# 446/768 --> Merged tokens (274, 282) into token 701
# 447/768 --> Merged tokens (108, 267) into token 702
# 448/768 --> Merged tokens (292, 480) into token 703
# 449/768 --> Merged tokens (332, 291) into token 704
# 450/768 --> Merged tokens (97, 100) into token 705
# 451/768 --> Merged tokens (363, 258) into token 706
# 452/768 --> Merged tokens (303, 263) into token 707
# 453/768 --> Merged tokens (99, 292) into token 708
# 454/768 --> Merged tokens (389, 256) into token 709
# 455/768 --> Merged tokens (385, 105) into token 710
# 456/768 --> Merged tokens (273, 290) into token 711
# 457/768 --> Merged tokens (112, 325) into token 712
# 458/768 --> Merged tokens (430, 256) into token 713
# 459/768 --> Merged tokens (264, 277) into token 714
# 460/768 --> Merged tokens (296, 269) into token 715
# 461/768 --> Merged tokens (401, 257) into token 716
# 462/768 --> Merged tokens (326, 101) into token 717
# 463/768 --> Merged tokens (295, 524) into token 718
# 464/768 --> Merged tokens (271, 299) into token 719
# 465/768 --> Merged tokens (328, 10) into token 720
# 466/768 --> Merged tokens (301, 257) into token 721
# 467/768 --> Merged tokens (332, 108) into token 722
# 468/768 --> Merged tokens (109, 98) into token 723
# 469/768 --> Merged tokens (102, 287) into token 724
# 470/768 --> Merged tokens (116, 354) into token 725
# 471/768 --> Merged tokens (384, 411) into token 726
# 472/768 --> Merged tokens (428, 262) into token 727
# 473/768 --> Merged tokens (68, 289) into token 728
# 474/768 --> Merged tokens (312, 284) into token 729
# 475/768 --> Merged tokens (350, 259) into token 730
# 476/768 --> Merged tokens (111, 309) into token 731
# 477/768 --> Merged tokens (555, 39) into token 732
# 478/768 --> Merged tokens (478, 446) into token 733
# 479/768 --> Merged tokens (352, 356) into token 734
# 480/768 --> Merged tokens (108, 325) into token 735
# 481/768 --> Merged tokens (264, 424) into token 736
# 482/768 --> Merged tokens (328, 266) into token 737
# 483/768 --> Merged tokens (336, 101) into token 738
# 484/768 --> Merged tokens (118, 351) into token 739
# 485/768 --> Merged tokens (292, 101) into token 740
# 486/768 --> Merged tokens (271, 317) into token 741
# 487/768 --> Merged tokens (105, 257) into token 742
# 488/768 --> Merged tokens (102, 421) into token 743
# 489/768 --> Merged tokens (103, 645) into token 744
# 490/768 --> Merged tokens (39, 289) into token 745
# 491/768 --> Merged tokens (285, 273) into token 746
# 492/768 --> Merged tokens (315, 371) into token 747
# 493/768 --> Merged tokens (256, 344) into token 748
# 494/768 --> Merged tokens (99, 475) into token 749
# 495/768 --> Merged tokens (117, 285) into token 750
# 496/768 --> Merged tokens (301, 259) into token 751
# 497/768 --> Merged tokens (265, 264) into token 752
# 498/768 --> Merged tokens (63, 10) into token 753
# 499/768 --> Merged tokens (415, 256) into token 754
# 500/768 --> Merged tokens (384, 322) into token 755
# 501/768 --> Merged tokens (294, 256) into token 756
# 502/768 --> Merged tokens (274, 265) into token 757
# 503/768 --> Merged tokens (118, 265) into token 758
# 504/768 --> Merged tokens (597, 256) into token 759
# 505/768 --> Merged tokens (99, 282) into token 760
# 506/768 --> Merged tokens (360, 323) into token 761
# 507/768 --> Merged tokens (267, 316) into token 762
# 508/768 --> Merged tokens (280, 110) into token 763
# 509/768 --> Merged tokens (351, 259) into token 764
# 510/768 --> Merged tokens (97, 381) into token 765
# 511/768 --> Merged tokens (435, 405) into token 766
# 512/768 --> Merged tokens (635, 310) into token 767
# 513/768 --> Merged tokens (76, 257) into token 768
# 514/768 --> Merged tokens (100, 497) into token 769
# 515/768 --> Merged tokens (326, 320) into token 770
# 516/768 --> Merged tokens (332, 311) into token 771
# 517/768 --> Merged tokens (99, 323) into token 772
# 518/768 --> Merged tokens (323, 318) into token 773
# 519/768 --> Merged tokens (512, 411) into token 774
# 520/768 --> Merged tokens (323, 272) into token 775
# 521/768 --> Merged tokens (313, 271) into token 776
# 522/768 --> Merged tokens (364, 101) into token 777
# 523/768 --> Merged tokens (439, 258) into token 778
# 524/768 --> Merged tokens (302, 271) into token 779
# 525/768 --> Merged tokens (109, 306) into token 780
# 526/768 --> Merged tokens (257, 310) into token 781
# 527/768 --> Merged tokens (112, 112) into token 782
# 528/768 --> Merged tokens (629, 446) into token 783
# 529/768 --> Merged tokens (358, 258) into token 784
# 530/768 --> Merged tokens (455, 418) into token 785
# 531/768 --> Merged tokens (256, 271) into token 786
# 532/768 --> Merged tokens (102, 341) into token 787
# 533/768 --> Merged tokens (105, 338) into token 788
# 534/768 --> Merged tokens (78, 400) into token 789
# 535/768 --> Merged tokens (256, 312) into token 790
# 536/768 --> Merged tokens (112, 523) into token 791
# 537/768 --> Merged tokens (103, 282) into token 792
# 538/768 --> Merged tokens (305, 422) into token 793
# 539/768 --> Merged tokens (115, 377) into token 794
# 540/768 --> Merged tokens (319, 283) into token 795
# 541/768 --> Merged tokens (257, 280) into token 796
# 542/768 --> Merged tokens (347, 288) into token 797
# 543/768 --> Merged tokens (97, 359) into token 798
# 544/768 --> Merged tokens (305, 276) into token 799
# 545/768 --> Merged tokens (116, 338) into token 800
# 546/768 --> Merged tokens (386, 449) into token 801
# 547/768 --> Merged tokens (114, 351) into token 802
# 548/768 --> Merged tokens (100, 280) into token 803
# 549/768 --> Merged tokens (272, 257) into token 804
# 550/768 --> Merged tokens (103, 277) into token 805
# 551/768 --> Merged tokens (97, 311) into token 806
# 552/768 --> Merged tokens (630, 356) into token 807
# 553/768 --> Merged tokens (328, 276) into token 808
# 554/768 --> Merged tokens (76, 259) into token 809
# 555/768 --> Merged tokens (323, 32) into token 810
# 556/768 --> Merged tokens (467, 32) into token 811
# 557/768 --> Merged tokens (375, 259) into token 812
# 558/768 --> Merged tokens (430, 257) into token 813
# 559/768 --> Merged tokens (100, 427) into token 814
# 560/768 --> Merged tokens (101, 314) into token 815
# 561/768 --> Merged tokens (331, 256) into token 816
# 562/768 --> Merged tokens (432, 259) into token 817
# 563/768 --> Merged tokens (97, 299) into token 818
# 564/768 --> Merged tokens (283, 258) into token 819
# 565/768 --> Merged tokens (101, 109) into token 820
# 566/768 --> Merged tokens (101, 322) into token 821
# 567/768 --> Merged tokens (295, 407) into token 822
# 568/768 --> Merged tokens (595, 311) into token 823
# 569/768 --> Merged tokens (307, 325) into token 824
# 570/768 --> Merged tokens (303, 10) into token 825
# 571/768 --> Merged tokens (483, 289) into token 826
# 572/768 --> Merged tokens (282, 447) into token 827
# 573/768 --> Merged tokens (409, 258) into token 828
# 574/768 --> Merged tokens (473, 301) into token 829
# 575/768 --> Merged tokens (97, 102) into token 830
# 576/768 --> Merged tokens (364, 260) into token 831
# 577/768 --> Merged tokens (281, 419) into token 832
# 578/768 --> Merged tokens (109, 284) into token 833
# 579/768 --> Merged tokens (111, 449) into token 834
# 580/768 --> Merged tokens (259, 304) into token 835
# 581/768 --> Merged tokens (382, 399) into token 836
# 582/768 --> Merged tokens (110, 105) into token 837
# 583/768 --> Merged tokens (109, 260) into token 838
# 584/768 --> Merged tokens (370, 407) into token 839
# 585/768 --> Merged tokens (303, 266) into token 840
# 586/768 --> Merged tokens (364, 416) into token 841
# 587/768 --> Merged tokens (372, 258) into token 842
# 588/768 --> Merged tokens (498, 256) into token 843
# 589/768 --> Merged tokens (294, 482) into token 844
# 590/768 --> Merged tokens (285, 99) into token 845
# 591/768 --> Merged tokens (372, 279) into token 846
# 592/768 --> Merged tokens (290, 276) into token 847
# 593/768 --> Merged tokens (116, 39) into token 848
# 594/768 --> Merged tokens (346, 262) into token 849
# 595/768 --> Merged tokens (312, 532) into token 850
# 596/768 --> Merged tokens (452, 338) into token 851
# 597/768 --> Merged tokens (102, 268) into token 852
# 598/768 --> Merged tokens (100, 302) into token 853
# 599/768 --> Merged tokens (365, 451) into token 854
# 600/768 --> Merged tokens (264, 266) into token 855
# 601/768 --> Merged tokens (80, 111) into token 856
# 602/768 --> Merged tokens (409, 371) into token 857
# 603/768 --> Merged tokens (296, 309) into token 858
# 604/768 --> Merged tokens (80, 105) into token 859
# 605/768 --> Merged tokens (417, 100) into token 860
# 606/768 --> Merged tokens (66, 101) into token 861
# 607/768 --> Merged tokens (292, 257) into token 862
# 608/768 --> Merged tokens (58, 32) into token 863
# 609/768 --> Merged tokens (282, 110) into token 864
# 610/768 --> Merged tokens (320, 355) into token 865
# 611/768 --> Merged tokens (675, 342) into token 866
# 612/768 --> Merged tokens (115, 272) into token 867
# 613/768 --> Merged tokens (102, 297) into token 868
# 614/768 --> Merged tokens (256, 257) into token 869
# 615/768 --> Merged tokens (413, 111) into token 870
# 616/768 --> Merged tokens (256, 304) into token 871
# 617/768 --> Merged tokens (365, 310) into token 872
# 618/768 --> Merged tokens (264, 422) into token 873
# 619/768 --> Merged tokens (102, 265) into token 874
# 620/768 --> Merged tokens (264, 578) into token 875
# 621/768 --> Merged tokens (402, 270) into token 876
# 622/768 --> Merged tokens (307, 287) into token 877
# 623/768 --> Merged tokens (369, 271) into token 878
# 624/768 --> Merged tokens (115, 284) into token 879
# 625/768 --> Merged tokens (793, 437) into token 880
# 626/768 --> Merged tokens (97, 350) into token 881
# 627/768 --> Merged tokens (335, 258) into token 882
# 628/768 --> Merged tokens (112, 282) into token 883
# 629/768 --> Merged tokens (327, 257) into token 884
# 630/768 --> Merged tokens (299, 280) into token 885
# 631/768 --> Merged tokens (39, 262) into token 886
# 632/768 --> Merged tokens (260, 406) into token 887
# 633/768 --> Merged tokens (98, 290) into token 888
# 634/768 --> Merged tokens (305, 109) into token 889
# 635/768 --> Merged tokens (448, 507) into token 890
# 636/768 --> Merged tokens (84, 117) into token 891
# 637/768 --> Merged tokens (346, 101) into token 892
# 638/768 --> Merged tokens (115, 560) into token 893
# 639/768 --> Merged tokens (336, 266) into token 894
# 640/768 --> Merged tokens (861, 97) into token 895
# 641/768 --> Merged tokens (111, 118) into token 896
# 642/768 --> Merged tokens (324, 271) into token 897
# 643/768 --> Merged tokens (616, 356) into token 898
# 644/768 --> Merged tokens (99, 284) into token 899
# 645/768 --> Merged tokens (312, 268) into token 900
# 646/768 --> Merged tokens (117, 258) into token 901
# 647/768 --> Merged tokens (273, 439) into token 902
# 648/768 --> Merged tokens (360, 371) into token 903
# 649/768 --> Merged tokens (508, 280) into token 904
# 650/768 --> Merged tokens (305, 348) into token 905
# 651/768 --> Merged tokens (99, 99) into token 906
# 652/768 --> Merged tokens (285, 336) into token 907
# 653/768 --> Merged tokens (97, 379) into token 908
# 654/768 --> Merged tokens (80, 482) into token 909
# 655/768 --> Merged tokens (517, 328) into token 910
# 656/768 --> Merged tokens (302, 281) into token 911
# 657/768 --> Merged tokens (98, 260) into token 912
# 658/768 --> Merged tokens (347, 339) into token 913
# 659/768 --> Merged tokens (264, 854) into token 914
# 660/768 --> Merged tokens (116, 341) into token 915
# 661/768 --> Merged tokens (382, 257) into token 916
# 662/768 --> Merged tokens (332, 449) into token 917
# 663/768 --> Merged tokens (98, 398) into token 918
# 664/768 --> Merged tokens (264, 10) into token 919
# 665/768 --> Merged tokens (102, 493) into token 920
# 666/768 --> Merged tokens (315, 628) into token 921
# 667/768 --> Merged tokens (97, 105) into token 922
# 668/768 --> Merged tokens (308, 100) into token 923
# 669/768 --> Merged tokens (110, 258) into token 924
# 670/768 --> Merged tokens (300, 258) into token 925
# 671/768 --> Merged tokens (337, 265) into token 926
# 672/768 --> Merged tokens (438, 632) into token 927
# 673/768 --> Merged tokens (102, 304) into token 928
# 674/768 --> Merged tokens (112, 287) into token 929
# 675/768 --> Merged tokens (276, 426) into token 930
# 676/768 --> Merged tokens (308, 278) into token 931
# 677/768 --> Merged tokens (312, 495) into token 932
# 678/768 --> Merged tokens (334, 317) into token 933
# 679/768 --> Merged tokens (303, 112) into token 934
# 680/768 --> Merged tokens (101, 420) into token 935
# 681/768 --> Merged tokens (274, 818) into token 936
# 682/768 --> Merged tokens (295, 273) into token 937
# 683/768 --> Merged tokens (353, 10) into token 938
# 684/768 --> Merged tokens (612, 626) into token 939
# 685/768 --> Merged tokens (336, 10) into token 940
# 686/768 --> Merged tokens (336, 257) into token 941
# 687/768 --> Merged tokens (282, 296) into token 942
# 688/768 --> Merged tokens (353, 262) into token 943
# 689/768 --> Merged tokens (418, 257) into token 944
# 690/768 --> Merged tokens (256, 333) into token 945
# 691/768 --> Merged tokens (372, 118) into token 946
# 692/768 --> Merged tokens (112, 503) into token 947
# 693/768 --> Merged tokens (97, 295) into token 948
# 694/768 --> Merged tokens (103, 257) into token 949
# 695/768 --> Merged tokens (365, 411) into token 950
# 696/768 --> Merged tokens (508, 114) into token 951
# 697/768 --> Merged tokens (348, 718) into token 952
# 698/768 --> Merged tokens (273, 258) into token 953
# 699/768 --> Merged tokens (117, 418) into token 954
# 700/768 --> Merged tokens (116, 268) into token 955
# 701/768 --> Merged tokens (271, 464) into token 956
# 702/768 --> Merged tokens (99, 265) into token 957
# 703/768 --> Merged tokens (895, 489) into token 958
# 704/768 --> Merged tokens (357, 268) into token 959
# 705/768 --> Merged tokens (377, 117) into token 960
# 706/768 --> Merged tokens (76, 39) into token 961
# 707/768 --> Merged tokens (283, 105) into token 962
# 708/768 --> Merged tokens (295, 359) into token 963
# 709/768 --> Merged tokens (98, 268) into token 964
# 710/768 --> Merged tokens (307, 111) into token 965
# 711/768 --> Merged tokens (401, 400) into token 966
# 712/768 --> Merged tokens (363, 256) into token 967
# 713/768 --> Merged tokens (401, 287) into token 968
# 714/768 --> Merged tokens (277, 565) into token 969
# 715/768 --> Merged tokens (668, 259) into token 970
# 716/768 --> Merged tokens (280, 364) into token 971
# 717/768 --> Merged tokens (100, 313) into token 972
# 718/768 --> Merged tokens (669, 487) into token 973
# 719/768 --> Merged tokens (100, 437) into token 974
# 720/768 --> Merged tokens (99, 39) into token 975
# 721/768 --> Merged tokens (704, 256) into token 976
# 722/768 --> Merged tokens (279, 256) into token 977
# 723/768 --> Merged tokens (118, 259) into token 978
# 724/768 --> Merged tokens (86, 105) into token 979
# 725/768 --> Merged tokens (294, 114) into token 980
# 726/768 --> Merged tokens (315, 290) into token 981
# 727/768 --> Merged tokens (115, 282) into token 982
# 728/768 --> Merged tokens (432, 257) into token 983
# 729/768 --> Merged tokens (362, 442) into token 984
# 730/768 --> Merged tokens (118, 39) into token 985
# 731/768 --> Merged tokens (367, 103) into token 986
# 732/768 --> Merged tokens (611, 257) into token 987
# 733/768 --> Merged tokens (332, 101) into token 988
# 734/768 --> Merged tokens (415, 258) into token 989
# 735/768 --> Merged tokens (102, 673) into token 990
# 736/768 --> Merged tokens (103, 557) into token 991
# 737/768 --> Merged tokens (319, 451) into token 992
# 738/768 --> Merged tokens (264, 459) into token 993
# 739/768 --> Merged tokens (380, 283) into token 994
# 740/768 --> Merged tokens (110, 39) into token 995
# 741/768 --> Merged tokens (80, 275) into token 996
# 742/768 --> Merged tokens (274, 257) into token 997
# 743/768 --> Merged tokens (264, 109) into token 998
# 744/768 --> Merged tokens (321, 101) into token 999
# 745/768 --> Merged tokens (305, 350) into token 1000
# 746/768 --> Merged tokens (277, 412) into token 1001
# 747/768 --> Merged tokens (282, 637) into token 1002
# 748/768 --> Merged tokens (100, 331) into token 1003
# 749/768 --> Merged tokens (111, 263) into token 1004
# 750/768 --> Merged tokens (100, 324) into token 1005
# 751/768 --> Merged tokens (305, 623) into token 1006
# 752/768 --> Merged tokens (285, 391) into token 1007
# 753/768 --> Merged tokens (280, 273) into token 1008
# 754/768 --> Merged tokens (285, 266) into token 1009
# 755/768 --> Merged tokens (68, 258) into token 1010
# 756/768 --> Merged tokens (79, 391) into token 1011
# 757/768 --> Merged tokens (435, 110) into token 1012
# 758/768 --> Merged tokens (105, 111) into token 1013
# 759/768 --> Merged tokens (353, 269) into token 1014
# 760/768 --> Merged tokens (282, 766) into token 1015
# 761/768 --> Merged tokens (340, 101) into token 1016
# 762/768 --> Merged tokens (367, 299) into token 1017
# 763/768 --> Merged tokens (105, 309) into token 1018
# 764/768 --> Merged tokens (299, 285) into token 1019
# 765/768 --> Merged tokens (109, 302) into token 1020
# 766/768 --> Merged tokens (664, 288) into token 1021
# 767/768 --> Merged tokens (105, 346) into token 1022
# 768/768 --> Merged tokens (332, 613) into token 1023

# %%
# Check if the state of the tokenizer should be saved
if save_state:
    # Save the state of the tokenizer
    tokenizer.save(output_path)

# %% [markdown]
# ### Evaluation

# %%
# Encoding the text
encoded_text = tokenizer.encode(validation_text)

# Decoding the text
decoded_text = tokenizer.decode(encoded_text)

# Print the original text
print(f"Original text")
print("-------------")
print(validation_text)

# Print the encoded text
print("\nEncoded text")
print("------------")
print(encoded_text)

# Print the decoded text
print("\nDecoded text")
print("------------")
print(decoded_text)
# Out:
# Original text
# -------------
# , quel principio ond'elli indige,
# tal era io a quella vista nova:
# veder volea come si convenne
# l'imago al cerchio e come vi s'indova;
# se non che la mia mente fu percossa
# da un fulgore in che sua voglia venne.
# l'amor che move il sole e l'altre stelle.
#
# Encoded text
# ------------
# [44, 32, 300, 108, 32, 382, 110, 292, 326, 111, 32, 287, 100, 39, 439, 105, 32, 282, 285, 519, 266, 652, 32, 260, 97, 32, 1013, 32, 97, 32, 498, 97, 32, 937, 97, 32, 277, 624, 381, 308, 585, 32, 367, 101, 97, 32, 264, 353, 32, 336, 32, 348, 385, 329, 10, 108, 39, 1022, 672, 32, 284, 32, 553, 377, 111, 32, 101, 32, 264, 353, 32, 295, 32, 115, 39, 282, 386, 624, 309, 305, 32, 277, 110, 32, 261, 101, 32, 455, 32, 315, 97, 32, 387, 296, 32, 335, 32, 379, 264, 283, 97, 10, 100, 97, 32, 325, 32, 335, 108, 103, 272, 101, 32, 282, 32, 261, 101, 32, 294, 97, 32, 857, 97, 32, 385, 329, 276, 108, 39, 775, 32, 261, 101, 32, 380, 308, 32, 105, 108, 32, 500, 101, 32, 101, 32, 108, 39, 363, 101, 32, 902, 101, 46]
#
# Decoded text
# ------------
# , quel principio ond'elli indige,
# tal era io a quella vista nova:
# veder volea come si convenne
# l'imago al cerchio e come vi s'indova;
# se non che la mia mente fu percossa
# da un fulgore in che sua voglia venne.
# l'amor che move il sole e l'altre stelle.
