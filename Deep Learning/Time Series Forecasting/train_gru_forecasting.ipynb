# %%
import os
import sys
import numpy as np
from pathlib import Path
from datetime import datetime
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# Import utility functions
from utils import (
    load_data, 
    compute_log_returns, 
    directional_accuracy,
    compute_realized_volatility,
    build_sequences
)

# Add the path to the custom library to the system path
sys.path.append(str(Path().resolve().parent))

# Import the module from the custom library
from src.models import TrainingArguments, LabeledData
from src.core.utils import data_analysis, data_processing, context_manager
from src import Tensor, layers, loss_functions, optimizers, metrics, callbacks
from src.architectures.auto_regressive import AutoRegressive, AutoRegressiveConfig

# %% [markdown]
# ### Constants and Hyperparameters

# %%
# Path to where the model will be saved
model_path = os.path.join(os.getcwd(), 'checkpoints', 'stock_prediction_gru')
dataset_path = os.path.join(os.getcwd(), 'dataset', 'SPX.csv')

# Define the feature and target columns
feature_columns = ['Open', 'High', 'Low', 'Close']
close_price_idx = feature_columns.index('Close')

# %%
# Hyperparameters for the model
train_test_split_pct = 0.05
train_valid_split_pct = 0.1
learning_rate = 3e-4
max_seq_len = 48
batch_size = 64
epochs = 50
seed = 1234

# Volatility window size (number of periods to compute realized volatility)
volatility_window = 5

# %%
# Set the seed for reproducibility
np.random.seed(seed)

# %% [markdown]
# ### Data loading

# %%
# Load the data
data = load_data(dataset_path)

# Print the number of data points and the date range
print(f"Loaded {len(data)} data points")
print(f"Date range: {data[0]['Date']} to {data[-1]['Date']}")
# Out:
# Loaded 23323 data points
# Date range: 1927-12-30 to 2020-11-04

# %%
# Extract the feature and timestamp data
features = np.array([[np.float32(data[j][k]) for k in feature_columns] for j in range(len(data))])
timestamps = np.array([datetime.strptime(data[j]['Date'], '%Y-%m-%d').timestamp() for j in range(len(data))], dtype=np.int32)

# Print the shapes of the features and dates arrays
print(f"Price data shape: {features.shape}")
print(f"Timestamps shape: {timestamps.shape}")
# Out:
# Price data shape: (23323, 4)
# Timestamps shape: (23323,)

# %% [markdown]
# ### Features engineering

# %%
# Compute log returns
log_returns = compute_log_returns(features)
timestamps_returns = timestamps[1:]

# Print the shape and statistics of the log returns
print(f"Log returns shape: {log_returns.shape}")
print(f"Log returns stats - Mean: {np.mean(log_returns, axis=0)}")
print(f"Log returns stats - Std: {np.std(log_returns, axis=0)}")

# Compute realized volatility using a rolling window
realized_volatility = compute_realized_volatility(log_returns, volatility_window)

# Adjust timestamp for the volatility data
timestamps_volatility = timestamps_returns[volatility_window:]

# Print the shape and statistics of the realized volatility
print(f"\nRealized volatility shape: {realized_volatility.shape}")
print(f"Realized volatility stats - Mean: {np.mean(realized_volatility, axis=0)}")
print(f"Realized volatility stats - Std: {np.std(realized_volatility, axis=0)}")
# Out:
# Log returns shape: (23322, 4)
# Log returns stats - Mean: [0.00022563 0.00022662 0.00022561 0.00022609]
# Log returns stats - Std: [0.01179839 0.01105997 0.01168979 0.01202147]
#
# Realized volatility shape: (23317, 4)
# Realized volatility stats - Mean: [0.00917469 0.00854306 0.00900207 0.00929485]
# Realized volatility stats - Std: [0.00742147 0.00702609 0.00746039 0.00762645]

# %% [markdown]
# ### Data preprocessing

# %%
# Build sequences
features_data, targets_data, timestamps_returns_data = build_sequences(
    input_data = log_returns[volatility_window:],
    target_data = realized_volatility,
    timestamps = timestamps_volatility,
    seq_length = max_seq_len
    
)

# Convert to tensors
features, targets, timestamps = Tensor(features_data), Tensor(targets_data), Tensor(timestamps_returns_data)

# Print the shapes of the features and targets
print(f"Features shape: {features.shape}")
print(f"Targets shape: {targets.shape}")
print(f"Timestamps shape: {timestamps.shape}")
# Out:
# Features shape: (23269, 48, 4)
# Targets shape: (23269, 4)
# Timestamps shape: (23269,)

# %% [markdown]
# ### Data splitting

# %%
# Split the dataset into training, validation, and testing sets
(X_train, X_test, y_train, y_test), train_test_shuffle_indices = data_processing.split_data((features, targets), train_test_split_pct, shuffle=True)
(X_train, X_valid, y_train, y_valid), train_valid_shuffle_indices = data_processing.split_data((X_train, y_train), train_valid_split_pct, shuffle=True)

# Ensure the shuffle indices are numpy arrays
assert isinstance(train_test_shuffle_indices, np.ndarray), "train_test_shuffle_indices should be a numpy array"
assert isinstance(train_valid_shuffle_indices, np.ndarray), "train_valid_shuffle_indices should be a numpy array"

# Extract the timestamps for each set
train_timestamps, test_timestamps = data_processing.split_data(timestamps[train_test_shuffle_indices], train_test_split_pct, shuffle=False)[0]
train_timestamps, valid_timestamps = data_processing.split_data(train_timestamps[train_valid_shuffle_indices], train_valid_split_pct, shuffle=False)[0]

# Print the dataset information
print('Training set:', X_train.shape, y_train.shape)
print('Validation set:', X_valid.shape, y_valid.shape)
print('Testing set:', X_test.shape, y_test.shape)
# Out:
# Training set: (19896, 48, 4) (19896, 4)
# Validation set: (2210, 48, 4) (2210, 4)
# Testing set: (1163, 48, 4) (1163, 4)

# %% [markdown]
# ### Data normalization

# %%
# Compute normalization statistics from training data only
mean, std, min, max = data_processing.compute_stats(X=X_train, axis=(0, 1))

# Print the normalization statistics
print('Normalization statistics (from training data only):')
print('Min:', min.to_numpy())
print('Max:', max.to_numpy())
print('Mean:', mean.to_numpy())
print('Std:', std.to_numpy())
# Out:
# Normalization statistics (from training data only):
# Min: [-0.2280193  -0.14060071 -0.22485887 -0.22899728]
# Max: [0.1536613 0.1536613 0.1536613 0.1536613]
# Mean: [0.00021662 0.00021723 0.00021633 0.00021687]
# Std: [0.01184426 0.0110956  0.01173525 0.01207935]

# %%
# Normalize the training, validation, and test sets using training statistics
X_train_norm = data_processing.z_score_normalize(X_train, mean, std)
X_valid_norm = data_processing.z_score_normalize(X_valid, mean, std)
X_test_norm = data_processing.z_score_normalize(X_test, mean, std)

# %% [markdown]
# ### Building the model

# %%
# Define the model architecture
model = AutoRegressive(
    name = "Stock prediction model",
    config = AutoRegressiveConfig(
        return_sequence = False,
        use_cache = False,
        max_sequence_length = max_seq_len,
        input_type = 'continuous'
    ),
    modules = [
        layers.GRU(num_layers=2, num_units=64, dropout=0.3),
        layers.Dense(num_units=32),
        layers.Dropout(0.3),
        layers.Dense(num_units=y_train.shape[-1])
    ]
)

# Initialize the optimizer with lower learning rate
optimizer = optimizers.Adam(learning_rate=learning_rate)

# Initialize the loss function
loss_fn = loss_functions.MeanSquareError()

# %% [markdown]
# ### Initializing the model

# %%
# Call the model with a first batch to initialize the weights
# This is not necessary, but it is useful to know the input size

# Disable gradient computation
with context_manager.no_grad():
    # Set the model in evaluation mode
    model.eval()
    
    # Call the model with a batch of data to initialize it
    model(x=X_train_norm[:batch_size])

# %%
# Display model summary
model.summary(recursive=True)
# Out:
# Stock prediction model (AutoRegressive) [output_shape=(64, 4), params=40612]
# └── stock_prediction_model.modules (ModuleList) [output_shape=(64, 4), params=40612]
#     ├── module_list.0 (GRU) [output_shape=(64, 64), params=38400]
#     │   └── gru.dropout_layer (Dropout) [output_shape=(64, 64), params=0]
#     ├── module_list.1 (Dense) [output_shape=(64, 32), params=2080]
#     ├── module_list.2 (Dropout) [output_shape=(64, 32), params=0]
#     └── module_list.3 (Dense) [output_shape=(64, 4), params=132]

# %% [markdown]
# ### Training the model

# %%
# Create the training arguments
train_arguments = TrainingArguments(
    train_data = LabeledData(input={'x': X_train_norm}, target=y_train),
    valid_data = LabeledData(input={'x': X_valid_norm}, target=y_valid),
    optimizer = optimizer,
    loss_fn = loss_fn,
    train_batch_size = batch_size,
    num_epochs = epochs,
    metrics = [metrics.mean_absolute_error],
    callbacks = [callbacks.EarlyStopping(monitor="val_loss", patience=10)]
)

# Train the model
history = model.fit(train_arguments)
# Out:
# Epoch 1/50 --> loss: 0.00042218 - mean_absolute_error: 0.013698 | val_loss: 1.5193e-05 - val_mean_absolute_error: 0.0025571
# Epoch 2/50 --> loss: 8.1667e-05 - mean_absolute_error: 0.0063593 | val_loss: 8.7829e-06 - val_mean_absolute_error: 0.0017218
# Epoch 3/50 --> loss: 4.3701e-05 - mean_absolute_error: 0.0045965 | val_loss: 7.1742e-06 - val_mean_absolute_error: 0.0015129
# Epoch 4/50 --> loss: 2.904e-05 - mean_absolute_error: 0.0037034 | val_loss: 6.001e-06 - val_mean_absolute_error: 0.0014008
# Epoch 5/50 --> loss: 2.1731e-05 - mean_absolute_error: 0.0031689 | val_loss: 5.6886e-06 - val_mean_absolute_error: 0.0013736
# Epoch 6/50 --> loss: 1.6645e-05 - mean_absolute_error: 0.0027423 | val_loss: 5.1004e-06 - val_mean_absolute_error: 0.0012668
# Epoch 7/50 --> loss: 1.3812e-05 - mean_absolute_error: 0.0024719 | val_loss: 4.3864e-06 - val_mean_absolute_error: 0.0011806
# Epoch 8/50 --> loss: 1.2009e-05 - mean_absolute_error: 0.0022926 | val_loss: 4.2076e-06 - val_mean_absolute_error: 0.0011735
# Epoch 9/50 --> loss: 1.0489e-05 - mean_absolute_error: 0.0021228 | val_loss: 3.8166e-06 - val_mean_absolute_error: 0.0011224
# Epoch 10/50 --> loss: 9.0872e-06 - mean_absolute_error: 0.0019769 | val_loss: 4.3869e-06 - val_mean_absolute_error: 0.0011886
# Epoch 11/50 --> loss: 8.5306e-06 - mean_absolute_error: 0.001887 | val_loss: 4.5057e-06 - val_mean_absolute_error: 0.0012312
# Epoch 12/50 --> loss: 7.64e-06 - mean_absolute_error: 0.0018062 | val_loss: 3.487e-06 - val_mean_absolute_error: 0.0010864
# Epoch 13/50 --> loss: 7.3618e-06 - mean_absolute_error: 0.0017365 | val_loss: 3.6994e-06 - val_mean_absolute_error: 0.0011912
# Epoch 14/50 --> loss: 6.7943e-06 - mean_absolute_error: 0.0016819 | val_loss: 3.1545e-06 - val_mean_absolute_error: 0.0010858
# Epoch 15/50 --> loss: 6.3891e-06 - mean_absolute_error: 0.0016226 | val_loss: 3.3128e-06 - val_mean_absolute_error: 0.0011111
# Epoch 16/50 --> loss: 6.0358e-06 - mean_absolute_error: 0.0015855 | val_loss: 3.8049e-06 - val_mean_absolute_error: 0.0012192
# Epoch 17/50 --> loss: 5.3846e-06 - mean_absolute_error: 0.0015087 | val_loss: 3.0406e-06 - val_mean_absolute_error: 0.0010645
# Epoch 18/50 --> loss: 5.2561e-06 - mean_absolute_error: 0.001478 | val_loss: 2.8478e-06 - val_mean_absolute_error: 0.0010813
# Epoch 19/50 --> loss: 5.4348e-06 - mean_absolute_error: 0.0014729 | val_loss: 2.8471e-06 - val_mean_absolute_error: 0.001015
# Epoch 20/50 --> loss: 5.0622e-06 - mean_absolute_error: 0.0014532 | val_loss: 2.5817e-06 - val_mean_absolute_error: 0.0010027
# Epoch 21/50 --> loss: 4.7919e-06 - mean_absolute_error: 0.001412 | val_loss: 2.6297e-06 - val_mean_absolute_error: 0.0011046
# Epoch 22/50 --> loss: 4.7598e-06 - mean_absolute_error: 0.001399 | val_loss: 2.2456e-06 - val_mean_absolute_error: 0.00096749
# Epoch 23/50 --> loss: 4.4248e-06 - mean_absolute_error: 0.0013633 | val_loss: 2.6802e-06 - val_mean_absolute_error: 0.0010645
# Epoch 24/50 --> loss: 4.7083e-06 - mean_absolute_error: 0.0013715 | val_loss: 2.6883e-06 - val_mean_absolute_error: 0.0011548
# Epoch 25/50 --> loss: 4.577e-06 - mean_absolute_error: 0.0013577 | val_loss: 2.8806e-06 - val_mean_absolute_error: 0.0011115
# Epoch 26/50 --> loss: 4.3586e-06 - mean_absolute_error: 0.0013295 | val_loss: 2.4335e-06 - val_mean_absolute_error: 0.00098591
# Epoch 27/50 --> loss: 4.2089e-06 - mean_absolute_error: 0.00132 | val_loss: 2.4816e-06 - val_mean_absolute_error: 0.0010006
# Epoch 28/50 --> loss: 4.1809e-06 - mean_absolute_error: 0.0013007 | val_loss: 2.1816e-06 - val_mean_absolute_error: 0.0009861
# Epoch 29/50 --> loss: 4.1545e-06 - mean_absolute_error: 0.0012982 | val_loss: 2.1533e-06 - val_mean_absolute_error: 0.00094519
# Epoch 30/50 --> loss: 3.8669e-06 - mean_absolute_error: 0.0012672 | val_loss: 1.8646e-06 - val_mean_absolute_error: 0.0009218
# Epoch 31/50 --> loss: 4.0021e-06 - mean_absolute_error: 0.0012784 | val_loss: 1.8716e-06 - val_mean_absolute_error: 0.00090689
# Epoch 32/50 --> loss: 3.9272e-06 - mean_absolute_error: 0.0012622 | val_loss: 2.6727e-06 - val_mean_absolute_error: 0.0010492
# Epoch 33/50 --> loss: 4.0171e-06 - mean_absolute_error: 0.0012707 | val_loss: 2.417e-06 - val_mean_absolute_error: 0.0009749
# Epoch 34/50 --> loss: 3.769e-06 - mean_absolute_error: 0.001242 | val_loss: 1.6208e-06 - val_mean_absolute_error: 0.00082243
# Epoch 35/50 --> loss: 3.8018e-06 - mean_absolute_error: 0.0012473 | val_loss: 1.942e-06 - val_mean_absolute_error: 0.00089314
# Epoch 36/50 --> loss: 3.6972e-06 - mean_absolute_error: 0.0012297 | val_loss: 2.4431e-06 - val_mean_absolute_error: 0.00095442
# Epoch 37/50 --> loss: 3.752e-06 - mean_absolute_error: 0.0012255 | val_loss: 1.9633e-06 - val_mean_absolute_error: 0.00089354
# Epoch 38/50 --> loss: 3.6612e-06 - mean_absolute_error: 0.0012139 | val_loss: 2.1687e-06 - val_mean_absolute_error: 0.0008993
# Epoch 39/50 --> loss: 3.5435e-06 - mean_absolute_error: 0.001208 | val_loss: 1.5904e-06 - val_mean_absolute_error: 0.00080528
# Epoch 40/50 --> loss: 3.5785e-06 - mean_absolute_error: 0.0011915 | val_loss: 1.6911e-06 - val_mean_absolute_error: 0.00084479
# Epoch 41/50 --> loss: 3.447e-06 - mean_absolute_error: 0.0011836 | val_loss: 1.9443e-06 - val_mean_absolute_error: 0.00094205
# Epoch 42/50 --> loss: 3.5072e-06 - mean_absolute_error: 0.0011894 | val_loss: 1.4809e-06 - val_mean_absolute_error: 0.0007976
# Epoch 43/50 --> loss: 3.2959e-06 - mean_absolute_error: 0.0011675 | val_loss: 1.7369e-06 - val_mean_absolute_error: 0.00081075
# Epoch 44/50 --> loss: 3.5156e-06 - mean_absolute_error: 0.001184 | val_loss: 1.9682e-06 - val_mean_absolute_error: 0.00094001
# Epoch 45/50 --> loss: 3.4874e-06 - mean_absolute_error: 0.0011807 | val_loss: 1.3766e-06 - val_mean_absolute_error: 0.00078677
# Epoch 46/50 --> loss: 3.3186e-06 - mean_absolute_error: 0.0011567 | val_loss: 1.5048e-06 - val_mean_absolute_error: 0.00079848
# Epoch 47/50 --> loss: 3.2104e-06 - mean_absolute_error: 0.0011446 | val_loss: 1.6977e-06 - val_mean_absolute_error: 0.00083702
# Epoch 48/50 --> loss: 3.3172e-06 - mean_absolute_error: 0.0011554 | val_loss: 1.5191e-06 - val_mean_absolute_error: 0.00086629
# Epoch 49/50 --> loss: 3.2239e-06 - mean_absolute_error: 0.001152 | val_loss: 1.854e-06 - val_mean_absolute_error: 0.00091344
# Epoch 50/50 --> loss: 3.2653e-06 - mean_absolute_error: 0.0011547 | val_loss: 1.275e-06 - val_mean_absolute_error: 0.00076692

# %%
# Save the model
model.save(model_path)

# %%
# Plot training history
data_analysis.plot_history(
    train_loss = model.history["loss"],
    valid_loss = model.history["val_loss"],
    title = "Training and Validation Loss",
    xlabel = "Epoch",
    ylabel = "Loss"
)

# %% [markdown]
# ### Evaluation

# %%
# Disable gradient computation for evaluation
with context_manager.no_grad():
    # Set the model in evaluation mode
    model.eval()
    
    # Compute the predictions
    X_test_out = model(X_test_norm, batch_size=batch_size, verbose=True)
    predictions = X_test_out.output
# Out:
# Processing batch 19/19 - 53.35 ms/step

# %%
# Compute the mean absolute error on the test set
mae = metrics.mean_absolute_error(predictions, y_test)

# Print the test results
print(f"Test Results:")
print(f"Mean Absolute Error: {mae.to_numpy()}")

# Compute the directional accuracy
dir_acc = directional_accuracy(predictions.to_numpy(), y_test.to_numpy(), close_price_idx)

# Print the directional accuracy
print(f"Directional Accuracy: {dir_acc:.3f}")
# Out:
# Test Results:
# Mean Absolute Error: 0.00076783582335338
# Directional Accuracy: 0.955

# %%
# Prepare the plot object based on whether we are predicting volatility or log returns
plot_obj = "Realized Volatility"
samples_to_plot = 100  # Number of samples to plot

# Sort the test timestamps and corresponding predictions and true values
sorted_indices = np.argsort(test_timestamps.to_numpy())
sorted_test_timestamps = test_timestamps.to_numpy()[sorted_indices]
sorted_y_test = y_test.to_numpy()[sorted_indices]
sorted_predictions = predictions.to_numpy()[sorted_indices]

# Extract the test dates by converting timestamps to datetime
test_dates = np.array([datetime.fromtimestamp(int(t)) for t in sorted_test_timestamps])

# Create a figure for plotting
plt.figure(figsize=(15, 8))

# Plot the time series of true and predicted realized volatility
plt.subplot(2, 1, 1)
plt.plot(test_dates[-samples_to_plot:], sorted_y_test[-samples_to_plot:, close_price_idx], label=f'True {plot_obj}', alpha=0.7)
plt.plot(test_dates[-samples_to_plot:], sorted_predictions[-samples_to_plot:, close_price_idx], label=f'Predicted {plot_obj}', alpha=0.7)
plt.title(f'{plot_obj} Prediction Results')
plt.ylabel(plot_obj)
plt.legend()
plt.gca().xaxis.set_major_locator(MaxNLocator(nbins=20))
plt.xticks(rotation=45)

# Scatter plot of true vs predicted realized volatility
plt.subplot(2, 1, 2)
plt.scatter(y_test.to_numpy()[:, close_price_idx], predictions.to_numpy()[:, close_price_idx], alpha=0.5)
plt.plot(
    [y_test.to_numpy()[:, close_price_idx].min(), y_test.to_numpy()[:, close_price_idx].max()],
    [y_test.to_numpy()[:, close_price_idx].min(), y_test.to_numpy()[:, close_price_idx].max()],
    'r--', label='Perfect Prediction'
)
plt.xlabel(f'True {plot_obj}')
plt.ylabel(f'Predicted {plot_obj}')
plt.title('Prediction Scatter Plot')
plt.legend()

# Adjust layout and show the plot
plt.tight_layout()
plt.show()
