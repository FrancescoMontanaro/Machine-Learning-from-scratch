# %%
import os
import sys
import numpy as np
from pathlib import Path

# Add the path to the custom library to the system path
sys.path.append(str(Path().resolve().parent))

# Import the module from the custom library
from src.architectures.sequential import Sequential
from src.core.utils import data_analysis, data_processing, context_manager
from src import Tensor, TrainingArguments, layers, activations, loss_functions, optimizers, metrics, callbacks

# %% [markdown]
# ### Constants and Hyperparameters

# %%
# Path to where the model will be saved
model_path = os.path.join(os.getcwd(), 'checkpoints', 'sine_approximator')

# %%
n_samples = 1000 # Number of samples to generate
train_test_split_pct = 0.2 # Percentage of samples to use for testing
train_valid_split = 0.2 # Percentage of samples to use for validation
learning_rate = 3e-04 # Learning rate for the optimizer
batch_size = 32 # Number of samples to use for each batch
epochs = 300 # Number of epochs to train the model
seed = 1234 # Seed for reproducibility
data_noise = 0.15 # Noise to add to the data

# %%
# Set the seed for reproducibility
np.random.seed(seed)

# %% [markdown]
# ### Data loading

# %%
def generate_sine_dataset(n_samples: int, noise: float = 0.0) -> tuple[np.ndarray, np.ndarray]:
    """
    Method to generate a dataset of samples and targets of a sine function
    
    Parameters: 
    - n_samples (int): Number of samples to generate
    - noise float: Standard deviation of the Gaussian noise. Default is 0 (no noise)
    
    Returns:
    - tuple[np.ndarray, np.ndarray]: Features and target of the dataset
    """

    # Generate random samples
    X = np.random.uniform(-2*np.pi, 2*np.pi, (n_samples, 1)).astype(np.float32)

    # Compute the target
    y = np.sin(X) + np.random.normal(0, noise, (n_samples, 1)).astype(np.float32)
    
    # Return the dataset
    return X, y

# %%
# Generate the synthetic dataset of a sine function with some gaussian noise
X, y = generate_sine_dataset(n_samples, noise=data_noise)

# Convert the dataset to Tensor objects
X, y = Tensor(X), Tensor(y)

# Split the dataset into training, validation, and testing sets
X_train, X_test, y_train, y_test = data_processing.split_data((X, y), train_test_split_pct, shuffle=True)[0]
X_train, X_valid, y_train, y_valid = data_processing.split_data((X_train, y_train), train_valid_split, shuffle=True)[0]

# Print the dataset information
print('Training set:', X_train.shape, y_train.shape)
print('Validation set:', X_valid.shape, y_valid.shape)
print('Testing set:', X_test.shape, y_test.shape)
# Out:
# Training set: (640, 1) (640, 1)
# Validation set: (160, 1) (160, 1)
# Testing set: (200, 1) (200, 1)

# %% [markdown]
# ### Data visualization

# %%
data_analysis.plot_data(
    datasets = [
        {'points': np.array(list(zip(X_train.data, y_train.data))), 'label': "Sine function", 'color': "blue", 'size': 10, 'plot_type': 'scatter'},
    ],
    title = "Sine Function Dataset",
    xlabel = "X",
    ylabel = "y"
)

# %% [markdown]
# ### Building the model

# %%
# Create the model
model = Sequential(
    name = "Sine Function Approximator",
    modules = [
        layers.Dense(num_units=128, activation=activations.Tanh()),
        layers.Dense(num_units=64, activation=activations.Tanh()),
        layers.Dense(num_units=32, activation=activations.Tanh()),
        layers.Dense(num_units=1)
    ]
)

# Initialize the optimizer
optimizer = optimizers.Adam(
    learning_rate = learning_rate,
    weight_decay = 0.01
)

# Initialize the error function
loss_fn = loss_functions.MeanSquareError()

# %% [markdown]
# ### Initializing the model

# %%
# Call the model with a first batch to initialize the weights
# This is not necessary, but it is useful to know the input size

# Disable gradient computation
with context_manager.no_grad():
    # Set the model in evaluation mode
    model.eval()
    
    # Call the model with a batch of data to initialize it
    model(X_train[:batch_size])

# %%
# Display the model summary
model.summary()
model.modules.summary()
# Out:
# Sine Function Approximator
#
# -----------------------------------------------------------------------------------------------
# Module (type)                                          Output Shape        Trainable params #
# ===============================================================================================
# sine_function_approximator.modules (ModuleList)        (32, 1)             10625
# ===============================================================================================
# Total trainable parameters: 10625
# -----------------------------------------------------------------------------------------------
#
# sine_function_approximator.modules
#
# -----------------------------------------------------------------------------------------------
# Module (type)                                          Output Shape        Trainable params #
# ===============================================================================================
# module_list.0 (Dense)                                  (32, 128)           256
# -----------------------------------------------------------------------------------------------
# module_list.1 (Dense)                                  (32, 64)            8256
# -----------------------------------------------------------------------------------------------
# module_list.2 (Dense)                                  (32, 32)            2080
# -----------------------------------------------------------------------------------------------
# module_list.3 (Dense)                                  (32, 1)             33
# ===============================================================================================
# Total trainable parameters: 10625
# -----------------------------------------------------------------------------------------------

# %% [markdown]
# ### Training the model

# %%
# Create the training arguments
train_arguments = TrainingArguments(
    train_data = {'x': X_train},
    valid_data = {'x': X_valid},
    y_train = y_train,
    y_valid = y_valid,
    optimizer = optimizer,
    loss_fn = loss_fn,
    train_batch_size = batch_size,
    num_epochs = epochs,
    metrics = [metrics.mean_absolute_error],
    callbacks = [callbacks.EarlyStopping(monitor="val_loss", patience=10)]
)

# Fit the model
history = model.fit(train_arguments)
# Out:
# Epoch 1/300 --> loss: 0.47677 - mean absolute error: 0.60435 | Val loss: 0.4859 - Val mean absolute error: 0.6258
# Epoch 2/300 --> loss: 0.38264 - mean absolute error: 0.54392 | Val loss: 0.37391 - Val mean absolute error: 0.54183
# Epoch 3/300 --> loss: 0.2779 - mean absolute error: 0.45933 | Val loss: 0.25226 - Val mean absolute error: 0.44223
# Epoch 4/300 --> loss: 0.18437 - mean absolute error: 0.36658 | Val loss: 0.16625 - Val mean absolute error: 0.34439
# Epoch 5/300 --> loss: 0.13944 - mean absolute error: 0.29999 | Val loss: 0.14194 - Val mean absolute error: 0.29942
# Epoch 6/300 --> loss: 0.12944 - mean absolute error: 0.27945 | Val loss: 0.13825 - Val mean absolute error: 0.29041
# Epoch 7/300 --> loss: 0.12647 - mean absolute error: 0.27471 | Val loss: 0.13496 - Val mean absolute error: 0.29022
# Epoch 8/300 --> loss: 0.12456 - mean absolute error: 0.27402 | Val loss: 0.13734 - Val mean absolute error: 0.29951
# Epoch 9/300 --> loss: 0.12137 - mean absolute error: 0.27286 | Val loss: 0.13888 - Val mean absolute error: 0.30347
# Epoch 10/300 --> loss: 0.1182 - mean absolute error: 0.27125 | Val loss: 0.13122 - Val mean absolute error: 0.29412
# Epoch 11/300 --> loss: 0.11672 - mean absolute error: 0.26916 | Val loss: 0.12695 - Val mean absolute error: 0.28655
# Epoch 12/300 --> loss: 0.11714 - mean absolute error: 0.26755 | Val loss: 0.12519 - Val mean absolute error: 0.28418
# Epoch 13/300 --> loss: 0.11422 - mean absolute error: 0.26571 | Val loss: 0.12661 - Val mean absolute error: 0.29011
# Epoch 14/300 --> loss: 0.11358 - mean absolute error: 0.26484 | Val loss: 0.12349 - Val mean absolute error: 0.28089
# Epoch 15/300 --> loss: 0.11308 - mean absolute error: 0.2637 | Val loss: 0.1229 - Val mean absolute error: 0.28032
# Epoch 16/300 --> loss: 0.11105 - mean absolute error: 0.26357 | Val loss: 0.11966 - Val mean absolute error: 0.27977
# Epoch 17/300 --> loss: 0.10881 - mean absolute error: 0.25927 | Val loss: 0.12057 - Val mean absolute error: 0.28366
# Epoch 18/300 --> loss: 0.10923 - mean absolute error: 0.25922 | Val loss: 0.12708 - Val mean absolute error: 0.29199
# Epoch 19/300 --> loss: 0.10565 - mean absolute error: 0.25711 | Val loss: 0.11764 - Val mean absolute error: 0.28027
# Epoch 20/300 --> loss: 0.10786 - mean absolute error: 0.25872 | Val loss: 0.12548 - Val mean absolute error: 0.29005
# Epoch 21/300 --> loss: 0.10636 - mean absolute error: 0.2563 | Val loss: 0.11747 - Val mean absolute error: 0.28108
# Epoch 22/300 --> loss: 0.10185 - mean absolute error: 0.25302 | Val loss: 0.11566 - Val mean absolute error: 0.27852
# Epoch 23/300 --> loss: 0.10057 - mean absolute error: 0.25035 | Val loss: 0.11086 - Val mean absolute error: 0.27068
# Epoch 24/300 --> loss: 0.10129 - mean absolute error: 0.25328 | Val loss: 0.1103 - Val mean absolute error: 0.26926
# Epoch 25/300 --> loss: 0.10009 - mean absolute error: 0.24722 | Val loss: 0.10773 - Val mean absolute error: 0.26455
# Epoch 26/300 --> loss: 0.097818 - mean absolute error: 0.24645 | Val loss: 0.11206 - Val mean absolute error: 0.27323
# Epoch 27/300 --> loss: 0.09789 - mean absolute error: 0.24593 | Val loss: 0.10506 - Val mean absolute error: 0.26315
# Epoch 28/300 --> loss: 0.094342 - mean absolute error: 0.24167 | Val loss: 0.1041 - Val mean absolute error: 0.2622
# Epoch 29/300 --> loss: 0.092671 - mean absolute error: 0.24038 | Val loss: 0.10097 - Val mean absolute error: 0.25839
# Epoch 30/300 --> loss: 0.091693 - mean absolute error: 0.23723 | Val loss: 0.10155 - Val mean absolute error: 0.25743
# Epoch 31/300 --> loss: 0.090456 - mean absolute error: 0.23748 | Val loss: 0.098523 - Val mean absolute error: 0.25377
# Epoch 32/300 --> loss: 0.087588 - mean absolute error: 0.23073 | Val loss: 0.095712 - Val mean absolute error: 0.25139
# Epoch 33/300 --> loss: 0.089691 - mean absolute error: 0.23529 | Val loss: 0.093894 - Val mean absolute error: 0.24799
# Epoch 34/300 --> loss: 0.085884 - mean absolute error: 0.22973 | Val loss: 0.095143 - Val mean absolute error: 0.24831
# Epoch 35/300 --> loss: 0.082156 - mean absolute error: 0.22529 | Val loss: 0.090214 - Val mean absolute error: 0.24192
# Epoch 36/300 --> loss: 0.080959 - mean absolute error: 0.22294 | Val loss: 0.089297 - Val mean absolute error: 0.24195
# Epoch 37/300 --> loss: 0.07943 - mean absolute error: 0.22052 | Val loss: 0.085223 - Val mean absolute error: 0.23832
# Epoch 38/300 --> loss: 0.076413 - mean absolute error: 0.21589 | Val loss: 0.084617 - Val mean absolute error: 0.23439
# Epoch 39/300 --> loss: 0.073056 - mean absolute error: 0.21123 | Val loss: 0.080641 - Val mean absolute error: 0.22835
# Epoch 40/300 --> loss: 0.070859 - mean absolute error: 0.20744 | Val loss: 0.078338 - Val mean absolute error: 0.22457
# Epoch 41/300 --> loss: 0.069029 - mean absolute error: 0.20424 | Val loss: 0.07661 - Val mean absolute error: 0.22388
# Epoch 42/300 --> loss: 0.067009 - mean absolute error: 0.1998 | Val loss: 0.075052 - Val mean absolute error: 0.22329
# Epoch 43/300 --> loss: 0.064392 - mean absolute error: 0.19923 | Val loss: 0.07129 - Val mean absolute error: 0.215
# Epoch 44/300 --> loss: 0.062475 - mean absolute error: 0.19477 | Val loss: 0.070369 - Val mean absolute error: 0.20914
# Epoch 45/300 --> loss: 0.062651 - mean absolute error: 0.19263 | Val loss: 0.067811 - Val mean absolute error: 0.21156
# Epoch 46/300 --> loss: 0.058213 - mean absolute error: 0.18843 | Val loss: 0.065535 - Val mean absolute error: 0.20832
# Epoch 47/300 --> loss: 0.056197 - mean absolute error: 0.18381 | Val loss: 0.067583 - Val mean absolute error: 0.21321
# Epoch 48/300 --> loss: 0.057482 - mean absolute error: 0.1886 | Val loss: 0.062633 - Val mean absolute error: 0.20452
# Epoch 49/300 --> loss: 0.054796 - mean absolute error: 0.18275 | Val loss: 0.060166 - Val mean absolute error: 0.20155
# Epoch 50/300 --> loss: 0.052022 - mean absolute error: 0.17879 | Val loss: 0.057028 - Val mean absolute error: 0.19294
# Epoch 51/300 --> loss: 0.050769 - mean absolute error: 0.17587 | Val loss: 0.055678 - Val mean absolute error: 0.19247
# Epoch 52/300 --> loss: 0.049004 - mean absolute error: 0.17385 | Val loss: 0.056862 - Val mean absolute error: 0.19634
# Epoch 53/300 --> loss: 0.047346 - mean absolute error: 0.16979 | Val loss: 0.055364 - Val mean absolute error: 0.19429
# Epoch 54/300 --> loss: 0.047389 - mean absolute error: 0.17367 | Val loss: 0.052923 - Val mean absolute error: 0.187
# Epoch 55/300 --> loss: 0.045896 - mean absolute error: 0.16876 | Val loss: 0.056589 - Val mean absolute error: 0.197
# Epoch 56/300 --> loss: 0.046019 - mean absolute error: 0.17011 | Val loss: 0.050207 - Val mean absolute error: 0.17786
# Epoch 57/300 --> loss: 0.042698 - mean absolute error: 0.16315 | Val loss: 0.047895 - Val mean absolute error: 0.1788
# Epoch 58/300 --> loss: 0.042166 - mean absolute error: 0.16284 | Val loss: 0.048759 - Val mean absolute error: 0.18271
# Epoch 59/300 --> loss: 0.04326 - mean absolute error: 0.16538 | Val loss: 0.048756 - Val mean absolute error: 0.17665
# Epoch 60/300 --> loss: 0.040998 - mean absolute error: 0.16046 | Val loss: 0.046631 - Val mean absolute error: 0.17835
# Epoch 61/300 --> loss: 0.039363 - mean absolute error: 0.15762 | Val loss: 0.043559 - Val mean absolute error: 0.17162
# Epoch 62/300 --> loss: 0.038642 - mean absolute error: 0.15641 | Val loss: 0.043372 - Val mean absolute error: 0.17092
# Epoch 63/300 --> loss: 0.037599 - mean absolute error: 0.15399 | Val loss: 0.041097 - Val mean absolute error: 0.1657
# Epoch 64/300 --> loss: 0.037027 - mean absolute error: 0.15216 | Val loss: 0.044564 - Val mean absolute error: 0.17295
# Epoch 65/300 --> loss: 0.037487 - mean absolute error: 0.15504 | Val loss: 0.039163 - Val mean absolute error: 0.16133
# Epoch 66/300 --> loss: 0.036596 - mean absolute error: 0.15397 | Val loss: 0.038732 - Val mean absolute error: 0.16136
# Epoch 67/300 --> loss: 0.036759 - mean absolute error: 0.15396 | Val loss: 0.040136 - Val mean absolute error: 0.15827
# Epoch 68/300 --> loss: 0.034181 - mean absolute error: 0.14907 | Val loss: 0.037934 - Val mean absolute error: 0.16027
# Epoch 69/300 --> loss: 0.033757 - mean absolute error: 0.14743 | Val loss: 0.035447 - Val mean absolute error: 0.15478
# Epoch 70/300 --> loss: 0.032971 - mean absolute error: 0.14583 | Val loss: 0.034532 - Val mean absolute error: 0.15228
# Epoch 71/300 --> loss: 0.032575 - mean absolute error: 0.14348 | Val loss: 0.035039 - Val mean absolute error: 0.14888
# Epoch 72/300 --> loss: 0.032585 - mean absolute error: 0.14453 | Val loss: 0.032779 - Val mean absolute error: 0.1481
# Epoch 73/300 --> loss: 0.031891 - mean absolute error: 0.14207 | Val loss: 0.031975 - Val mean absolute error: 0.14577
# Epoch 74/300 --> loss: 0.030856 - mean absolute error: 0.1417 | Val loss: 0.0316 - Val mean absolute error: 0.14548
# Epoch 75/300 --> loss: 0.030482 - mean absolute error: 0.13978 | Val loss: 0.032329 - Val mean absolute error: 0.145
# Epoch 76/300 --> loss: 0.032839 - mean absolute error: 0.14709 | Val loss: 0.032373 - Val mean absolute error: 0.14786
# Epoch 77/300 --> loss: 0.034284 - mean absolute error: 0.14927 | Val loss: 0.031072 - Val mean absolute error: 0.14416
# Epoch 78/300 --> loss: 0.031206 - mean absolute error: 0.13995 | Val loss: 0.029871 - Val mean absolute error: 0.13933
# Epoch 79/300 --> loss: 0.029164 - mean absolute error: 0.13654 | Val loss: 0.030402 - Val mean absolute error: 0.14372
# Epoch 80/300 --> loss: 0.029481 - mean absolute error: 0.1384 | Val loss: 0.03269 - Val mean absolute error: 0.14945
# Epoch 81/300 --> loss: 0.028091 - mean absolute error: 0.1338 | Val loss: 0.027444 - Val mean absolute error: 0.13578
# Epoch 82/300 --> loss: 0.027394 - mean absolute error: 0.13274 | Val loss: 0.02739 - Val mean absolute error: 0.13524
# Epoch 83/300 --> loss: 0.028029 - mean absolute error: 0.13405 | Val loss: 0.027119 - Val mean absolute error: 0.13277
# Epoch 84/300 --> loss: 0.02746 - mean absolute error: 0.13243 | Val loss: 0.026913 - Val mean absolute error: 0.13435
# Epoch 85/300 --> loss: 0.027164 - mean absolute error: 0.13151 | Val loss: 0.026493 - Val mean absolute error: 0.13177
# Epoch 86/300 --> loss: 0.027298 - mean absolute error: 0.13233 | Val loss: 0.025865 - Val mean absolute error: 0.13167
# Epoch 87/300 --> loss: 0.027167 - mean absolute error: 0.1313 | Val loss: 0.02506 - Val mean absolute error: 0.12797
# Epoch 88/300 --> loss: 0.026857 - mean absolute error: 0.1309 | Val loss: 0.024637 - Val mean absolute error: 0.1268
# Epoch 89/300 --> loss: 0.027165 - mean absolute error: 0.13121 | Val loss: 0.027131 - Val mean absolute error: 0.13629
# Epoch 90/300 --> loss: 0.026585 - mean absolute error: 0.13034 | Val loss: 0.02416 - Val mean absolute error: 0.12696
# Epoch 91/300 --> loss: 0.027743 - mean absolute error: 0.13338 | Val loss: 0.024601 - Val mean absolute error: 0.12898
# Epoch 92/300 --> loss: 0.027734 - mean absolute error: 0.13203 | Val loss: 0.026151 - Val mean absolute error: 0.1337
# Epoch 93/300 --> loss: 0.026048 - mean absolute error: 0.12739 | Val loss: 0.024852 - Val mean absolute error: 0.12898
# Epoch 94/300 --> loss: 0.025705 - mean absolute error: 0.12761 | Val loss: 0.022971 - Val mean absolute error: 0.12404
# Epoch 95/300 --> loss: 0.025183 - mean absolute error: 0.12612 | Val loss: 0.02561 - Val mean absolute error: 0.13259
# Epoch 96/300 --> loss: 0.02622 - mean absolute error: 0.12909 | Val loss: 0.026016 - Val mean absolute error: 0.12754
# Epoch 97/300 --> loss: 0.025673 - mean absolute error: 0.12641 | Val loss: 0.022277 - Val mean absolute error: 0.12053
# Epoch 98/300 --> loss: 0.025483 - mean absolute error: 0.12678 | Val loss: 0.023 - Val mean absolute error: 0.121
# Epoch 99/300 --> loss: 0.025636 - mean absolute error: 0.12675 | Val loss: 0.022018 - Val mean absolute error: 0.11971
# Epoch 100/300 --> loss: 0.026014 - mean absolute error: 0.12883 | Val loss: 0.025779 - Val mean absolute error: 0.13325
# Epoch 101/300 --> loss: 0.024939 - mean absolute error: 0.12412 | Val loss: 0.02211 - Val mean absolute error: 0.122
# Epoch 102/300 --> loss: 0.02551 - mean absolute error: 0.12731 | Val loss: 0.022318 - Val mean absolute error: 0.12297
# Epoch 103/300 --> loss: 0.025043 - mean absolute error: 0.12543 | Val loss: 0.022071 - Val mean absolute error: 0.11825
# Epoch 104/300 --> loss: 0.025143 - mean absolute error: 0.12501 | Val loss: 0.021535 - Val mean absolute error: 0.11735
# Epoch 105/300 --> loss: 0.024944 - mean absolute error: 0.12536 | Val loss: 0.022745 - Val mean absolute error: 0.1246
# Epoch 106/300 --> loss: 0.024831 - mean absolute error: 0.12522 | Val loss: 0.024927 - Val mean absolute error: 0.13082
# Epoch 107/300 --> loss: 0.025322 - mean absolute error: 0.12478 | Val loss: 0.021245 - Val mean absolute error: 0.11943
# Epoch 108/300 --> loss: 0.02478 - mean absolute error: 0.12521 | Val loss: 0.021192 - Val mean absolute error: 0.1187
# Epoch 109/300 --> loss: 0.024573 - mean absolute error: 0.12412 | Val loss: 0.023361 - Val mean absolute error: 0.11942
# Epoch 110/300 --> loss: 0.026278 - mean absolute error: 0.13039 | Val loss: 0.022034 - Val mean absolute error: 0.1221
# Epoch 111/300 --> loss: 0.027007 - mean absolute error: 0.13265 | Val loss: 0.022163 - Val mean absolute error: 0.11789
# Epoch 112/300 --> loss: 0.026901 - mean absolute error: 0.13023 | Val loss: 0.020959 - Val mean absolute error: 0.11677
# Epoch 113/300 --> loss: 0.025071 - mean absolute error: 0.12497 | Val loss: 0.021926 - Val mean absolute error: 0.1174
# Epoch 114/300 --> loss: 0.024358 - mean absolute error: 0.12289 | Val loss: 0.020503 - Val mean absolute error: 0.11519
# Epoch 115/300 --> loss: 0.02488 - mean absolute error: 0.12469 | Val loss: 0.024397 - Val mean absolute error: 0.12939
# Epoch 116/300 --> loss: 0.025843 - mean absolute error: 0.12707 | Val loss: 0.020837 - Val mean absolute error: 0.11516
# Epoch 117/300 --> loss: 0.025817 - mean absolute error: 0.12872 | Val loss: 0.023408 - Val mean absolute error: 0.12684
# Epoch 118/300 --> loss: 0.024363 - mean absolute error: 0.12511 | Val loss: 0.020671 - Val mean absolute error: 0.11482
# Epoch 119/300 --> loss: 0.024898 - mean absolute error: 0.12591 | Val loss: 0.020799 - Val mean absolute error: 0.1185
# Epoch 120/300 --> loss: 0.024217 - mean absolute error: 0.12271 | Val loss: 0.021147 - Val mean absolute error: 0.11771
# Epoch 121/300 --> loss: 0.024932 - mean absolute error: 0.12363 | Val loss: 0.020326 - Val mean absolute error: 0.11414
# Epoch 122/300 --> loss: 0.025445 - mean absolute error: 0.12495 | Val loss: 0.021774 - Val mean absolute error: 0.11989
# Epoch 123/300 --> loss: 0.025914 - mean absolute error: 0.12763 | Val loss: 0.021844 - Val mean absolute error: 0.12206
# Epoch 124/300 --> loss: 0.023878 - mean absolute error: 0.12161 | Val loss: 0.020606 - Val mean absolute error: 0.11414
# Epoch 125/300 --> loss: 0.02463 - mean absolute error: 0.1236 | Val loss: 0.021103 - Val mean absolute error: 0.11913
# Epoch 126/300 --> loss: 0.024401 - mean absolute error: 0.12384 | Val loss: 0.020402 - Val mean absolute error: 0.11696
# Epoch 127/300 --> loss: 0.024622 - mean absolute error: 0.12495 | Val loss: 0.020183 - Val mean absolute error: 0.11552
# Epoch 128/300 --> loss: 0.024225 - mean absolute error: 0.12292 | Val loss: 0.021028 - Val mean absolute error: 0.11566
# Epoch 129/300 --> loss: 0.025831 - mean absolute error: 0.12861 | Val loss: 0.019963 - Val mean absolute error: 0.11456
# Epoch 130/300 --> loss: 0.026941 - mean absolute error: 0.13037 | Val loss: 0.020741 - Val mean absolute error: 0.11679
# Epoch 131/300 --> loss: 0.025404 - mean absolute error: 0.12701 | Val loss: 0.020877 - Val mean absolute error: 0.11399
# Epoch 132/300 --> loss: 0.025417 - mean absolute error: 0.12668 | Val loss: 0.020581 - Val mean absolute error: 0.11728
# Epoch 133/300 --> loss: 0.024342 - mean absolute error: 0.12276 | Val loss: 0.023368 - Val mean absolute error: 0.12601
# Epoch 134/300 --> loss: 0.025741 - mean absolute error: 0.12735 | Val loss: 0.020114 - Val mean absolute error: 0.11557
# Epoch 135/300 --> loss: 0.026735 - mean absolute error: 0.12895 | Val loss: 0.019956 - Val mean absolute error: 0.11501
# Epoch 136/300 --> loss: 0.024828 - mean absolute error: 0.12439 | Val loss: 0.020393 - Val mean absolute error: 0.11663
# Epoch 137/300 --> loss: 0.024626 - mean absolute error: 0.12331 | Val loss: 0.020166 - Val mean absolute error: 0.11381
# Epoch 138/300 --> loss: 0.02477 - mean absolute error: 0.12343 | Val loss: 0.020199 - Val mean absolute error: 0.11337
# Epoch 139/300 --> loss: 0.024482 - mean absolute error: 0.12263 | Val loss: 0.020842 - Val mean absolute error: 0.11844
# Epoch 140/300 --> loss: 0.025341 - mean absolute error: 0.12609 | Val loss: 0.023639 - Val mean absolute error: 0.11821
# Epoch 141/300 --> loss: 0.025265 - mean absolute error: 0.12704 | Val loss: 0.021198 - Val mean absolute error: 0.11936
# Epoch 142/300 --> loss: 0.025576 - mean absolute error: 0.12602 | Val loss: 0.02235 - Val mean absolute error: 0.11578
# Epoch 143/300 --> loss: 0.024772 - mean absolute error: 0.12427 | Val loss: 0.019773 - Val mean absolute error: 0.11436
# Epoch 144/300 --> loss: 0.023717 - mean absolute error: 0.12138 | Val loss: 0.022468 - Val mean absolute error: 0.12162
# Epoch 145/300 --> loss: 0.024463 - mean absolute error: 0.12334 | Val loss: 0.022072 - Val mean absolute error: 0.12204
# Epoch 146/300 --> loss: 0.024972 - mean absolute error: 0.12435 | Val loss: 0.021757 - Val mean absolute error: 0.12135
# Epoch 147/300 --> loss: 0.024977 - mean absolute error: 0.12505 | Val loss: 0.021613 - Val mean absolute error: 0.11974
# Epoch 148/300 --> loss: 0.024136 - mean absolute error: 0.12435 | Val loss: 0.023083 - Val mean absolute error: 0.12505
# Epoch 149/300 --> loss: 0.024507 - mean absolute error: 0.1242 | Val loss: 0.019906 - Val mean absolute error: 0.11343
# Epoch 150/300 --> loss: 0.023896 - mean absolute error: 0.12182 | Val loss: 0.020276 - Val mean absolute error: 0.11594
# Epoch 151/300 --> loss: 0.024552 - mean absolute error: 0.12422 | Val loss: 0.020545 - Val mean absolute error: 0.11596
# Epoch 152/300 --> loss: 0.024286 - mean absolute error: 0.1226 | Val loss: 0.020604 - Val mean absolute error: 0.11796
# Epoch 153/300 --> loss: 0.024247 - mean absolute error: 0.12284 | Val loss: 0.020594 - Val mean absolute error: 0.1156
# Early stopping: stopping training after 153 epochs.

# %%
# Save the model
model.save(model_path)

# %%
# Plot the training and validation loss
data_analysis.plot_history(
    train_loss = history["loss"], 
    valid_loss = history["val_loss"], 
    title = "Training and Validation Loss", 
    xlabel = "Epoch", 
    ylabel = "Loss"
)

# %% [markdown]
# ### Evaluation

# %%
# Disable gradient computation
with context_manager.no_grad():
    # Set the model in evaluation mode
    model.eval()
    
    # Compute the predictions
    predictions = model(X_test)

# %%
# Calculate the mean absolute error
mae = metrics.mean_absolute_error(y_test, predictions)

# Print the mean absolute error
print("Mean Absolute Error:", mae.data)
# Out:
# Mean Absolute Error: 0.12858161

# %%
# Plot the sine function and the model predictions
data_analysis.plot_data(
    datasets = [
        {'points': np.array(list(zip(X_train.data, y_train.data))), 'label': "Training samples", 'color': "blue", 'size': 10, 'plot_type': 'scatter'},
        {'points': np.array(list(zip(X_test.data, predictions.data))), 'label': "Learned function", 'color': "red", 'plot_type': 'line'}
    ],
    title = "Sine Function and Model Predictions",
    xlabel = "X",
    ylabel = "y"
)
